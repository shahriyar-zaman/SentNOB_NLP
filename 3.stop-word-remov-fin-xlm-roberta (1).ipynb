# %%
# !pip install ktrain
import ktrain
from ktrain import text
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting ktrain
#   Downloading ktrain-0.38.0.tar.gz (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 47.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.7.2)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.0.2)
# Requirement already satisfied: fastprogress>=0.1.21 in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.3.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ktrain) (21.3)
# Collecting langdetect (from ktrain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 55.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.42.1)
# Collecting cchardet (from ktrain)
#   Downloading cchardet-2.1.7.tar.gz (653 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.6/653.6 kB 45.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting chardet (from ktrain)
#   Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 16.7 MB/s eta 0:00:00
# Collecting syntok>1.3.3 (from ktrain)
#   Downloading syntok-1.4.4-py3-none-any.whl (24 kB)
# Collecting tika (from ktrain)
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.17.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (4.33.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.1.99)
# Collecting keras_bert>=0.86.0 (from ktrain)
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting whoosh (from ktrain)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 36.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras_bert>=0.86.0->ktrain) (1.23.5)
# Collecting keras-transformer==0.40.0 (from keras_bert>=0.86.0->ktrain)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: regex>2016 in /opt/conda/lib/python3.10/site-packages (from syntok>1.3.3->ktrain) (2023.6.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.16.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (4.66.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (1.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (3.1.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tika->ktrain) (68.0.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers>=4.17.0->ktrain) (2023.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers>=4.17.0->ktrain) (4.6.3)
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, cchardet, langdetect, tika
#   Building wheel for ktrain (setup.py) ... done
#   Created wheel for ktrain: filename=ktrain-0.38.0-py3-none-any.whl size=25319964 sha256=26e4cf264eb468beaacf993f8e0f514f9fc7b53a5443e735380dd869f2e540b2
#   Stored in directory: /root/.cache/pip/wheels/10/76/6b/5799f396ca78a8c38c7c6439a192ca88538a97cfb970946da5
#   Building wheel for keras_bert (setup.py) ... done
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33501 sha256=10d7e1d07e134bc9cc8071a81fa506db4bfb18d4b227e71e26c44cc180695982
#   Stored in directory: /root/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12287 sha256=68003f52416f780117944ab0f4f637e7660e0cf12ed9f2e17cde69541cd19549
#   Stored in directory: /root/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3943 sha256=ce5f606f0366e1707b825f7a2138733f0991aff55fd7b8a7240363521a0e6c41
#   Stored in directory: /root/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4653 sha256=581794d1fcb6af91bb9a0c5151b3bff4ed4b9bc956dfd8be5ce95783f10a9908
#   Stored in directory: /root/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14979 sha256=6b50d4eeacbc7d0afda45570c33bebc8022aca0d97b24915efc9e3b4ce33d2ba
#   Stored in directory: /root/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6946 sha256=accd0efc009c2bfd45357cb97b8e11342aa7bfbd44a6767ea2f2f7e3d544fdd6
#   Stored in directory: /root/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4968 sha256=f6fb057f4280fbe51d23a49acb112ae507628e3a310ab01250dc064a99277e20
#   Stored in directory: /root/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=df25de9337433b17b3536e7d29f5808b069c14684725075e164a5c73eb83343b
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for cchardet (setup.py) ... done
#   Created wheel for cchardet: filename=cchardet-2.1.7-cp310-cp310-linux_x86_64.whl size=133763 sha256=e27f5815efa24df18d4f109fe0134f54b2e122663ca9e6568dd7590b8093b2cb
#   Stored in directory: /root/.cache/pip/wheels/ee/e0/ab/e01326f15c59438d080b1496dbab8091e952ec72f35e3c437e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=19f93bb885733594d88ac528c954bcfc254417ee7d6d372acc9627583f8ca7bb
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32625 sha256=ced22c962de940099103caaf936091a0db1c5884b0db84247cf4aa660a8add5f
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention cchardet langdetect tika
# Installing collected packages: whoosh, cchardet, syntok, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, chardet, tika, keras-multi-head, keras-transformer, keras_bert, ktrain
# Successfully installed cchardet-2.1.7 chardet-5.2.0 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.38.0 langdetect-1.0.9 syntok-1.4.4 tika-2.6.0 whoosh-2.7.4
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
trainSet = pd.read_csv('/kaggle/input/sentnob-sentiment-analysis-in-noisy-bangla-texts/SentNoB Dataset/Train.csv')
testSet =  pd.read_csv('/kaggle/input/sentnob-sentiment-analysis-in-noisy-bangla-texts/SentNoB Dataset/Test.csv')

# %%
# !pip install bnltk
# !pip install bnlp-toolkit==4.0.0.dev4
# Out:
# Collecting bnltk
#   Downloading bnltk-0.7.6-py3-none-any.whl (11 kB)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from bnltk) (2.12.0)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (from bnltk) (2.12.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnltk) (1.23.5)
# Collecting sklearn (from bnltk)
#   Downloading sklearn-0.0.post10.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bnltk) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bnltk) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bnltk) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bnltk) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bnltk) (2023.7.22)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (1.51.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (0.4.13)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->bnltk) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow->bnltk) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow->bnltk) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow->bnltk) (1.11.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->bnltk) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->bnltk) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->bnltk) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->bnltk) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow->bnltk) (2.3.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow->bnltk) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->bnltk) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->bnltk) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->bnltk) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->bnltk) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->bnltk) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->bnltk) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->bnltk) (3.2.2)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post10-py3-none-any.whl size=2959 sha256=dd312b4986ce9196ca01a8d8543ddd008f4a51d9b4bc4182d4da6a2bc75ad3a3
#   Stored in directory: /root/.cache/pip/wheels/5b/f6/92/0173054cc528db7ffe7b0c7652a96c3102aab156a6da960387
# Successfully built sklearn
# Installing collected packages: sklearn, bnltk
# Successfully installed bnltk-0.7.6 sklearn-0.0.post10
# Collecting bnlp-toolkit==4.0.0.dev4
#   Downloading bnlp_toolkit-4.0.0.dev4-py3-none-any.whl (22 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (0.1.99)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (4.3.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (1.11.2)
# Collecting sklearn-crfsuite (from bnlp-toolkit==4.0.0.dev4)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (4.66.1)
# Collecting ftfy (from bnlp-toolkit==4.0.0.dev4)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.8 MB/s eta 0:00:00
# Collecting emoji==1.7.0 (from bnlp-toolkit==4.0.0.dev4)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (2.31.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/conda/lib/python3.10/site-packages (from ftfy->bnlp-toolkit==4.0.0.dev4) (0.2.6)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim->bnlp-toolkit==4.0.0.dev4) (6.3.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->bnlp-toolkit==4.0.0.dev4) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (2023.7.22)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite->bnlp-toolkit==4.0.0.dev4)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from sklearn-crfsuite->bnlp-toolkit==4.0.0.dev4) (0.9.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=89c38fdd0a4bf345c571a6ab57bf0d0313123b883597aeccee6e0a09c64d9434
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: python-crfsuite, emoji, sklearn-crfsuite, ftfy, bnlp-toolkit
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.8.0
#     Uninstalling emoji-2.8.0:
#       Successfully uninstalled emoji-2.8.0
# Successfully installed bnlp-toolkit-4.0.0.dev4 emoji-1.7.0 ftfy-6.1.1 python-crfsuite-0.9.9 sklearn-crfsuite-0.3.6

# %%
#Tokenizer
from bnlp import NLTKTokenizer
bnltk = NLTKTokenizer()

#for Train Set
for i in range(0,trainSet.shape[0]):
    text = bnltk.word_tokenize(trainSet['Data'][i])
    trainSet['Data'][i] = text
#For Test Set   
for i in range(0,testSet.shape[0]):
    text = bnltk.word_tokenize(testSet['Data'][i])
    testSet['Data'][i] = text

# %%
trainSet.head()
# Out:
#                                                 Data  Label
# 0  [মুগ্ধ, হয়ে, গেলাম, মামু., আর, তোমায়, কি, কমু....      1
# 1  [এই, কুত্তার, বাচ্চাদের, জন্য, দেশটা, আজ, এমন,...      2
# 2                    [ভাই, আপনার, কথাই, যাদু, রয়েছে]      1
# 3                   [উওরটা, আমার, অনেক, ভাল, লেগেছে]      1
# 4  [আমার, নিজের, গাড়ী, নিয়ে, কি, সাজেক, যেতে, পা...      0

# %%
# !pip install BnLemma
# Out:
# Collecting BnLemma
#   Downloading BnLemma-2.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: BnLemma
# Successfully installed BnLemma-2.1

# %%
testSet.head()
# Out:
#                                                 Data  Label
# 0  [স্বাস্থ্যবান, হতে, চাই, ,, আমি, বয়সের, তুলনায়...      0
# 1                 [ভাইয়া, নতুন, ভিডিও, আসে, না, কেন]      0
# 2  [সৌরভ, গাঙ্গুলী, ছাড়া, দাদাগিরি, কখনো, জমে, উঠ...      0
# 3  [ক্রিকেট, কে, বাচাতে, হলে, পাপকে, অতিশিগ্রিই, ...      2
# 4                     [আমিতো, সেই, ঝালপ্রিয়ো, মানুষ]      1

# %%
from bnlp import BengaliCorpus as corpus

# print(corpus.stopwords)
# print(corpus.punctuations)
# print(corpus.letters)
# print(corpus.digits)
# print(corpus.vowels)

stop_words = set(corpus.stopwords)


for i in range(0,trainSet.shape[0]):
    words = trainSet['Data'][i]
    trainSet['Data'][i] =  [word for word in words if word.lower() not in stop_words]

# %%
# stop_words = set(corpus.stopwords)


for i in range(0,testSet.shape[0]):
    words = testSet['Data'][i]
    testSet['Data'][i] =  [word for word in words if word.lower() not in stop_words]

# %%
trainSet
# Out:
#                                                     Data  Label
# 0      [মুগ্ধ, হয়ে, গেলাম, মামু., তোমায়, কমু., বলো, ত...      1
# 1      [কুত্তার, বাচ্চাদের, দেশটা, অবস্তায়, তিনটা, পু...      2
# 2                               [ভাই, কথাই, যাদু, রয়েছে]      1
# 3                                   [উওরটা, ভাল, লেগেছে]      1
# 4             [গাড়ী, সাজেক, পারবো, ?, প্রাইভেট, কার, ?]      0
# ...                                                  ...    ...
# 12570  [বর্ডারে, লেট, হয়ে, যাওয়াতে, জিপে, যাই, বিকাল,...      1
# 12571  [সোনার, বাংলাতে, রক্ষক, নামের, ভক্ষকের, জায়গা,...      2
# 12572  [ওনারা, হাইজিনিক, সুন্দর, পরিবেশে, রান্না, বাস...      1
# 12573         [বাংলাদেশ, পুলিশ, চাই, ধরনে, পুলিশ, দরকার]      2
# 12574  [বসুন্ধরা, শাখার, হাজি, বিরিয়ানি, একবারেই, ফালতু]      2
#
# [12575 rows x 2 columns]

# %%
trainSet['Data'] = trainSet['Data'].apply(' '.join)

# %%
testSet['Data'] = testSet['Data'].apply(' '.join)

# %%
from sklearn.model_selection import train_test_split
train = trainSet['Data'].values.tolist()
test = testSet['Data'].values.tolist()
train_cluster_id = trainSet['Label'].tolist()
test_cluster_id = testSet['Label'].tolist()

# %%
X_train = train
y_train = train_cluster_id
X_test = test
y_test = test_cluster_id

# %%
X_train
# Out:
# ['মুগ্ধ হয়ে গেলাম মামু. তোমায় কমু. বলো তোমায় কোথায় পামু. সাথে যাবু. গান কমু গলি ঘুরমু.',
#  'কুত্তার বাচ্চাদের দেশটা অবস্তায় তিনটা পুলিশ তরে মেরে পেলা দরকার',
#  'ভাই কথাই যাদু রয়েছে',
#  'উওরটা ভাল লেগেছে',
#  'গাড়ী সাজেক পারবো ? প্রাইভেট কার ?',
#  ': পরীক্ষার রেজাল্টের সময় , ব্যানিজ্যিক প্রচার',
#  'বিশ্বনন্দিত বিশ্ব জয় ইসলামের পাখিদের কোরআনের পাখিদের খবর আরিফ অব্যয় বোদার বয় সিঙ্গেল বয় জাতি হিসেবে বাঙালি বর্তমানে মুরুক্ষ তারই প্রমাণ ঝাড়ু মার তোর কপালে',
#  'সাপ্তাহিক মুসুল্লিদের কথাটাও ধরলে ভাই , চোখ খুলে দিছো',
#  'ভেবেছিলাম গালিগালাজ সেরা ছেলে ? গালিবয়',
#  'রেপারই হও , ডাক্তার হওয়ার দরকার',
#  'লেসবো মেয়েটার ফ্রেন্ড টা কিউট',
#  'আচ্ছা চারপাশে অন্ধকার ? লাইট টা আপনাদের টেবিলে পড়ছে',
#  'আল্লাহ আপনাকে হায়াত দারাজ করুন মাঝে সুস্থ বেঁচে থাকার তৌফিক দান করুক',
#  'ভাই এতো সুন্দর ভিডিও বানান সাবস্ক্রাইবার বাড়ে কেনো ?',
#  'সাধারন মানুষ অন্যাই । রাজনীতি ব্যাক্তি পুলিশ । এক্তাই প্রশ্ন সাহস দিছে',
#  'ভাই দয়াকরে খাবার নষ্ট করবেন্না',
#  'এইসব ফকির ফাকরা রেপার হইবো কন্ঠ শুনে ডেন্ডি খায় বাল পাকনা পোলা ক্লাস ফাইভ সরকারি স্কুলে ফ্রী পড়াশোনা ক্লাস ওয়ানে বেতন । যত্তসব আজাইরা কথাবার্তা । আরেক আবাল পাগল হালায় ওরে ভাইরাল দুইটা গাঞ্জা খোর',
#  'চ্যানেল খবর গুলা ভালো লাগে । কারন যতটুকুম মারে সত্তি খবর দেয়',
#  'হিজরাদের রিপোর্ট যন্ত্রণায় মানুষ অতিষ্ঠ হয়ে',
#  'ভিডিও ভোজন বিলাস হচ্ছেন আল্লাহ হাসপাতাল',
#  'জরিমানা শাস্তি দেয়া , জরিমানা দিয়ে',
#  'ভাল্লাগছেরে ভাই খুব্বব্বব্বব',
#  'দাদা বাড়িটাই বানিয়েছেন , !',
#  'বাংলাদেশ কুকুর দামআচে পুলিশ দাম',
#  'নাচ দেইখা আমারো খাইতে ইচ্ছা',
#  'ভালো লাগল বিউটি বোডিং । শুনেছি বাংলাদেশ সাধীনতা ইতিহাস সাথে একাত্ত্ব বোডিং হাউস',
#  'বন্ধু জাহিদের শুভকামনা',
#  'আমলিগ দেশটা শেষ দিবে',
#  'সেদিন আপনাকে হাসের মাংস খাওয়ার সময় দেখেছি । ভাল লেগেছে । ভেবেছিলাম পরিচিত হই । ভেবে দলের সাথে ব্যস্ত হলাম',
#  'কুখ্যাত হাসিনার পুলিশলীগ মানেই ক্যাসিনো',
#  'সরকারের আকুল আবেদন পুলিশদেরকে আইনের আওতায় আনার কঠিন শান্তি দেয়ার',
#  'ভাইয়া আপু আপনাদের ফ্যান । অসাধারণ ভালো লাগলো আপনাদের ভ্লগটা । দারুন সুন্দর বর্ণনা খাবারের সবকিছু মিলিয়ে খুবিই সুন্দর । মুগ্ধকরা । তথ্যও গেলো । শুভ কামনা রইলো আপনাদের ভ্লগের উত্তরোত্তর সাফল্য কামনা করছি । ভালো থাকুন সবসময়',
#  'ভার্সিটি , প্রত্যেকটা কলেজে ছাত্রলীগ সাধারন ছাত্রদের অত্যাচার',
#  'ঢাবি , ঢাকা কলেজ , ইডেন , সাস্ট , জাবি প্রত্যেকটা পাবলিক ভাসিটিতে অবস্থা । এডমিশন টেষ্ট দেয়ার সময় র\u200d্যাগিন খেয়ে এসেছি',
#  'হ্যা চলাফেরা ছেলেদের মতই । অনেকের সাতে কথা বলেছি । মেনেজাও এরকম ছিলো',
#  'মারা খেয়ে গেছি । খাবার বাঙ্গালী জীভের উপযুক্ত',
#  'কলকাতাকে শহর । বাঙালি চিরন্তন ❤',
#  'ভাই ভিডিও অাপলোড অাগে ভালো কথা শিখুন দয়া ঠিকমত বাংলা ভাষাটা শিখে ভিডিও অাপলোড দিবেন',
#  'বাংলাদেশের সবাইকে দেশ ভারতে আসার আবেদন করছি । আপনারা আসুন দেশের খাবার দাবার মজা নিন । টুরিস্ট স্পট ঘুরুন মজা করুন',
#  'ভাই পুরা সাপ্তাহেই পাওয়া যায় অফ',
#  'ডিপেন্ড লাইফ স্টাইলের । পার হেড 6 - 9000 টাকা',
#  'ব্যাকগ্রাউন্ড মানুষ তাকার আসে এলিয়ন দেখতাসে',
#  'পাপন একটা শয়তান । যেণ মাননীয় প্রধানমন্ত্রী লাথি মাইরা বোট সরায় অনুরুধ রইল প্রধান মন্ত্রী',
#  'ভাই , একদিন ইসলামি বিশ্ববিদ্যালয় কুষ্টিয়ায় আসেন',
#  'অনেকবার গেছি অই রেষ্টুরেন্ট । ভর্তা গুলা অসাধার',
#  'বছর আগের ইচ্ছা বালি তে যাব । যেসব প্রসেসিং লাগে জানি',
#  'ভাই , আপনাদের ট্যুর যোগদান নিয়মাবলি ? জানালে খুশি হবো',
#  'ভাই রাব্বানী হটেলে খাইছি ১৯৯৫ সালে ২০১৯',
#  'ভাইয়া বিরাল কুথাথেকে কিনছেন',
#  'কয়েকটা শুয়ারেরবাচ্চা ঘুষখোর পুলিশের কর্মকান্ড গুলো',
#  'ভুটানে একা যেয়ে পুশাবে । ঐখানে পাব্লিক বাস খুবই কম । বললেই । ঐখানে শেয়ারড ট্যাক্সি পাবেন',
#  'বাংলাদেশকে নিচে নামালে তোদের মত পাঠারা শান্তি পাবি । আল্লা তোদের শেষ আল্লাই ভালো যানে',
#  'পুলিশের জাত , ধ্রম , জরম্ম পরিচয় পলতে , আল্লাহর তেইরি শয়তানের চেয়ে শয়তান',
#  'আশরাফুল পাপন ভাগ দেয়নাই লোকমান ভাগ দিছে । বেপারটা বুঝতে',
#  'আসলেই বাংগালীদের মহারাজ',
#  'আপনারা খারাপ ইন্ডিয়া নাচিন । বাংলাদেশ টাকি ইন্ডিয়া বানাতি ছাড়া বাংলাদেশ লোক অনুষ্ঠান । আপনাগো ছাগলের অবস্থা',
#  'ভাই কথাও এইটাই , কমেন্টস টা কিনা দেখার খুজতেছি । ধন্যবাদ ভাই',
#  'এইহানে , আ * * * * জারজ ? । কুত্তার পোলাগুলা',
#  'ছোট । তুই বড় বলধ একটা',
#  'আল্লাহওয়ালা মানুষের দেশ কিভাবে দুর্নীতে তে চ্যাম্পিয়ন মাঝে মাঝে বুঝে উঠতে',
#  'মন্ত্রী এমপিদের বাড়ীতে পারলে রেড দে । তহন বুঝা যাইবো তোদের পায়ের তলায় মাটি কতটুকু',
#  'অতীত ইতিহাস ! যমুনা টিভি পারবে সঠিক তত্থ উন্মোচন',
#  'ভাই আফনার বিডিও গুলা খোব ভাল সভ সময় দেখি , সৌদিআরবে থাকি',
#  'মুসলামানরা জেনে এক্সিডেনটালি পর্ক খেয়ে ফেললে পাপ জাত যায় । ইসলাম মতে পাপ শুধুমাত্র সজ্ঞান ইচ্ছাকৃত কাজের',
#  '* এগুলো বড়লোক জানোয়ারের বাচ্চাদের',
#  'ভাই নুডুলসটা বাংলাদেশ কোথায় পাবো । ঝাল নুডুলস অনেল পছন্দ',
#  'ফার্মের মুরগি , পাকিস্তানি মুরগী , দেশী মুরগী মুরগীইতো দেশে উৎপাদন তারপরেও দেশী মুরগী আলাদা',
#  'অাগে বংশাল নতুর চৌরাস্তায় মজিবরের ফুচকার দোকানে চপ দিয়ে চটপটি বানাতো',
#  'একজন সুপারহিরোকে আপনারা লুকিয়ে রেখেছেন',
#  'বিঝাই যাচেচ লাভ খুবই সিমিত',
#  'বাবা মারা লোভী , টাকার গন্ধ পেয়েছে । ঢাকায় মিছিল ঘুনে ছেলের বিপক্ষে । লোভে আম ছালা যাই , ভন্ড সাধু সাবধান',
#  'রাজনীতি মানুষকে মনুষ্যত্ব শেখানোর পরিবর্তে পশু বানায় রাজনীতির দরকার ? ধিক্কার জানাতেও ঘৃনা । দেশের সর্বোচ্চ বিদ্যাপিঠের মেধাবীদের অবস্থা । কোথায় ঠেকেছে বিবেকবোধ , নৈতিকতা ধর্মীয় মূল্যবোধ',
#  'চলতে থাকলে সামনের দিনগুলোতে ধর্ষণের সেঞ্চুরি বাংলাদেশ সরকারকে নোবেল জয়ী',
#  'ভালো লাগলো ভাইজান । ভালোবাসা রইল কোলকাতা । দেশ বিদেশের আরো খাবারের পরিচিত হবার অপেক্ষায় রইলাম',
#  'তো দামি ক্যামেরা ছাড়া শ্যুট করছি । প্যানেল ছাড়া এডিট । পকেটে । প্লিজ ফিডব্যাক জানান',
#  'লোকমান যেহেতু মদ খায়না জুয়া খেলে । মদ জুয়া মাগি পাপন সাপ্লাই দেয় , পাপন তুই পাপী',
#  'ভাইয়া , আমিতো ঐদিকে জাইনাই , প্রসেসটাও । সরি : (',
#  'হা হা হা কাক্কু কথা',
#  'শরীর টা খুবই অসুস্থ গত 3 মাস যাবত বাইরে বের পারছি , ইউটিউবে ভিডিও দেখেই মনের মুখের সাধ মিটাচ্ছি , এজন্য ধন্যবাদ খালেদ সাইফুল্লাহ ভাইকে টিমকে । আপনাদের সাফল্য কামনা',
#  'গে দের সচরাচর মেয়ে বান্ধবি',
#  'সনির গুলিটা ভুলে লাগছে আার আবরার পরিকল্পিত মার্ডার',
#  'বুয়েট সারা বাংলাদেশের শিক্ষাপ্রতিষ্ঠানগুলোতে ছাত্র রাজনীতি নিষিদ্ধ ঘোষণা',
#  'দার্জিলিং মাকে চুদবে খানির ছাওয়াল । দার্জিলিং বাল ? দেশের টাকা গুলো মালাউনদের দিয়ে আসাছাড়া',
#  'ইউইউ হানি সিং বাদ দিয়ে রানাকে বিশ্ব সেরা রেপার হিসেবে চায়',
#  'ইসলামি আইন পর্দা প্রথা কঠোর',
#  'ভিডিও গুলো সত্যই প্রাণবন্ত , বিষয় বস্তু উপস্থাপনা অনবদ্য । পুরানো দিনের স্নিগ্ধ স্মৃতি',
#  'ওয়েট করাইছেন সায়েম ভাই',
#  'ভুলেও এইখানে যাবেননা । বাজে',
#  'বাঞ্চোদেরা একটা গরীবের টাকাও মেরে খেলো , একটু বিবেকে বাদলো',
#  'বাংলাদেশে সমস্যাটি গুরুতর । আইন সমান',
#  'মাঝে মাঝে যাই মানগত খাবার',
#  'ভাই মানিকগঞ্জ খিচুড়ি খাওয়ার ঢাকা আসার দরকার । অন্যকাজে আসেন , ট্রাই । ডিসক্রিপশনে এড্রেস ডিটেইলস দেয়া',
#  'বাংলাদেশের একমাত্র আছেন নাম্বার ওয়ান ইউটিউবার খাবারের',
#  'পদানশিল মহিলা হতো টাকা ছারা আপনাকে ভালোবাসত',
#  '- ফোনর চেয়ে হুয়াও বেটার',
#  'কোথাও অন্যায় অবিচার অত্যাচার রেস্টুরেন্টের অভাব দেখলে রুখে দাঁড়ান',
#  'শিশুর ধর্ষন বন্ধ যুদি অপরাধীর ফাঁসি দেয়া',
#  'সুদূর ভারতে হাদরাবাদের নিজাম । বাংলা দেশে ? রাজাকার সাপোর্টার থাকলে ব্যাপার । অবাক হলাম',
#  'ব্যক্তিগত মাইক্রোবাসে সাজেক সম্ভব',
#  '* ভিডিও লাইক ? *',
#  'ভর দুপুরে খাবার ভীষণ লোভ লাগল দাদা , দিদি পেলে ভালো লাগত',
#  'আদনান ভাই নাটক দুরন্ত টিভিতে',
#  'আপনাদের চ্যানেল সহকর্মী',
#  'ভাই খাবারটা দেখলেই চোখ গুলা যেইভাবে চকচক , মাঝে মাঝে এইবার চোখ দিয়েই বোধহয় খাবেন',
#  'টাকা দিলে হসপিটালে দোভাষী পাবেন',
#  'সেষ জীবনে প্রধান মন্ত্রীর সাহাজ্য লাগবে',
#  'হিল্লোলের সাফাই গাওয়ার । আমিও বাংলাদেশের মানুষ । হিল্লোলের মত শ্যালো মানুষ দেখি নি',
#  'সায়েম ভাইয়া ফ্যামিলি সাথে ভ্রমন সংগী চাই',
#  'পুলিশ মানে যারজ আচোদা খানকির পোলারা , মা বইনরে ভারা দিয়াতো টাকা কামাইতে সাধারন মানুষের টাকা খায়কে , সাংবাদিক গটনাটা মিডিয়ায় আসছে , সাধারন জনগন জানতোই গটনা পতি রাতেই , শুয়েরের বাচ্চারা ছিনতাই',
#  'ক্যামেরা অতিরিক্ত সাদা হয়ে যাচ্ছিলো , প্লেসমেন্ট',
#  'ভিডিও গুলোর আরো একটু এডিটিং প্রয়োজন । বড্ডো একঘেয়ে লাগে মাঝেমাঝে',
#  'ভাই আপনে খান কেনো আপু খায়',
#  'বাচ্চাদের নিজেরাই খাচ্ছে !',
#  'হসিটা সত্যি দূর্দান্ত',
#  'উন্নত বিশ্বের কর্মসংস্থান দিলে মূল সমাজের সাথে মিশতে দিলে সমস্যা',
#  'ফকিন্নির পুতেরা রাজনীতি ঢুকে তখনই রকমই । একটা সময় জমিদারের পোলায় বাংলায় রাজনীতি । জিন্দেগীতে টাকাপয়সা দেখেনাই এগুলো রাজনীতি অবস্থা এরকমই নিশ্চিত । এটাও সত্য ছাত্র রাজনীতি উঠে অবশ্যই ছাত্রদের অস্তিত্ব হারিয়ে',
#  'স্বপ্নতে স্বপ্নের বাস্তবায়ন করুক',
#  'ভিডিও বোঝা যায়নি ? , ! তাহলেতো কষ্টটাই বৃথা : (',
#  'ইরানের একটাই শক্তি , নিজস্ব প্রযুক্তির উন্নত মিছাইল ব্যবস্থা',
#  'ওটা সমস্যা জাতির আব্বার দেশ খুশির ঠেলায় এরকম',
#  'দুঃখের ব্যাপার ধুমপান\u200cই ইয়াবা ফাঁসানো',
#  'পোলাও , গরুরমাংসো , রোস্ট সবকিছুই ভয়াবহ অতিরিক্ত তেল জবজবে',
#  'ফাহিম ভাইরে নিয়া যাইতেন । আরো খাওয়ার রিভিউ পারতেন',
#  'খানকির পুলা তর ভাগমান সম্পরকে বলছি তুই আল্লাহ সম্পরকে বলবি',
#  'উবুদের গেলেন খেলেন নৌকায় কেনো উঠলেন',
#  'তোমরা শব্দ উচ্চারণ জান খবর গলি বয় । গালি তোমরা শুদ্ধ শব্দের অর্থের বারোটা বাজিয়ে দাও',
#  'হালিম জীবনের একটা অবিচ্ছেদ্য অংশ < 3',
#  'পানসি রিভিউ শ্রীমঙ্গলের টা উচিৎ । সিলেটের টা',
#  '2050 সালে 900 সিসি বাইক বাংলাদেশে আসবে ইনশাআল্লাহ',
#  'ভাইয়া খাবারের ক্লোজ শট নেবেন আশা',
#  'চেহারা দেখেই বুঝা যায় হাতির মালিক পতি দারিদ্র্যতার সাথে যুদ্ধ টিকে , পেটের দায়ে । দয়া কর্মসংস্থানের ব্যবস্থাটাও । কখনো ভেবে দেখছেন ফ্যামিলির অবস্থা',
#  'ভাবিকে একটু বেশিই ঝাল লাকছে',
#  'খুবই ভাল লাগলো , ভিডিও সময় দেখি । আমিও একজন ভ্রমন পিপাষু হিসেবে উপভোগ । ধন্যবাদ',
#  'এইগুলো পুলিশ কুততালীগ',
#  'মত কমেন্ট পড়তে আসছ হাত তুলো । ✋',
#  'সত্যিকারের বাঙালি খাদ্যরসিক বটে',
#  'আসুন সঠিক ৫ ওয়াক্ত নামাজ আদাই',
#  'মেয়েদেরকে 1কোটি টাকা , পরিবার সুখে থাকুক',
#  'দিণে দুপুরে ডাকাতি বাংলা দেশে',
#  'ধরনের খাবার ভিডিও ভোর রাতে শুয়ে শুয়ে দেখলে কেমন লাগে ভাবতে',
#  'হিল্লোল ভাই প্রতিটা পর্ব দেখি ভাললাগে । চালিয়ে যাবেন ইনশাআল্লাহ',
#  'আল্লাহ তায়ালার রহমতে জীবন পেল * পেলে',
#  'টাকা টা ওনার দিয়ি',
#  '১০ ১২ টা ভিডিও ফেললাম দারুন লাগলো । আন্তরিক ভালোবাসা অভিনন্দন রইল ভারত',
#  'অসাধারন প্রেজেনটেশন',
#  'খালেদ ভাইয়া ভিডিও গুলা খুল ভালো',
#  'ধরেনা ক্যান বোকা চোদারা কথা বলার মানে 1 : 18 তুই শালা নিজেও বোকা চোদা দারায়া দারায়া তামাশা দেখতা ছোছ',
#  'সকালে গুহ্যদ্বার পরিমাণ জ্বলবে , এইটা ভেবে খেতেন',
#  'চারপাশে প্রতিভাবান মানুষ , পরিবেশগত কারনে প্রতিবা প্রকাশ পারেনা',
#  'তোর বাপের টাকা তুই হিজ্রা হয়েও , ছেলে সেজে গাল ফ্রেন্ড ঘুরছিস । জাতি তোকে চিনতে',
#  'মানুষদের এভাবে খাই । পুলিশ পলিথিন',
#  'সবাইকে একটাই অনুরোধ , খারাপ পুলিশ কর্মকর্তাদের অপরাধের কারণে বাংলাদেশ পুলিশকে গালি - গালাজ নাহ',
#  'এইসমস্ত মোবাইল ফোন কেনা সাধ্যের বাইরে সামর্থ্য একটা কথা । তারাই কিনতে পারবে আয়ের উৎস অফিসিয়াল লোকজন',
#  'অমি জেল বলছি লেখা ? অমি হয়ে',
#  'যতদিন পুলিশ সন্ত্রাস গুলাকে ক্রসফায়ার মারা ততদিন দেশে শান্তি আসবে পুলিশের ভিতরে ঢুকতে তারপরে দেশের জনগণের',
#  'জায়গায় পুলিশ দেখবেন গণ ধোলাই দিবেন এইসব সাহস পাবে',
#  'কলকাতায় গিয়েছিলাম , যাবো ইনশাহআল্লাহ , লাভ ইউ কলকাতা',
#  'ভাই ক্যামেরাতে নরমাল মুড ভিডিও',
#  'প্যরাডাইস বিরিয়ানির খাবার খুবই সুস্বাদু । গতবছর হায়দারাবাদে খেয়েছিলাম',
#  'ভাইজান আপনের ভিডিও দিখী ভালো লাগে থ্যাংকস',
#  'ভজহরি মান্না মস্কো তে',
#  'পাপন সালা তুই চুর , আশরাফুল বাংলাদেশকে ক্রিকেট বিশ্বে মাতা উচু টাই জুগিয়ে , তুই পিকসিন দায়ে ৫ বছর বাইরে রাখছ আার বলছ আইন দেরি থাকতে পারব , তোর বাপ লাগে ক্যাসেনো সাথে জড়িত ভরিসকার করছ',
#  'রাতাটা সবুজের বরপুর , ভাল পরিবেশ',
#  'বাংলাদেশের একেক দোকানের বিরিয়ানি একেক । এতো বিরিয়ানির ভিডিও দেখানো',
#  'ততোদিন সমাজের যিনা , জাহেলিয়াত দুর হবেনা',
#  '2 । ভ্রমন ভিসা দিনের',
#  'ভাই , ফ্রীতে খাইলে সবই বেহেশ্তী লাগে',
#  'পচা চুদা বাংলাদেশের কুন গরীবেরা বিচার পাবে',
#  'আল্লাহ্ তাআলার রহমত আলহামদু লিল্লাহ্',
#  'ঢাবি , ঢাকা কলেজ , ইডেন , সাস্ট , জাবি প্রত্যেকটা পাবলিক ভাসিটিতে অবস্থা । এডমিশন টেষ্ট দেয়ার সময় র\u200d্যাগিন খেয়ে এসেছি',
#  'বাচ্চা ত এক্তু দিলেই পারতেন । গরিব বাচ্চা কাসে খেতে গিয়েছিল কাজতা থিক ভাই',
#  'ছাগলের মত কমেন্ট । যতসব । আরে ভাই এসব রেগুলার খাইনা নাম জরুরি ? আপনারাও খান নি । দেশের মাঝেও খাবার সবখানে এক । ভারত বাংলাদেশ হিসেব বাংগালীর হিসেব করুন দাদারা । দাওয়াত রইলো',
#  'বাংলাদেশে কখন ১০০০ সিসির মোটরসাইকেল আসবে',
#  'পুরো পর্ব সুনাম শুনলাম , অনুযায়ী রেটিং টা কমই । রেটিং টা কেনো কম একটু ব্যাখ্যা করতেন সামনের পর্বগুলোতে , আশা আরোও ভালো লাগবে । লাগছে । ♥',
#  'খালেদ সাইফুল্লাহ আপনে টমেটো হোসেন',
#  'প্রবলেম রে ভাই , হুদাই ওটস খাবার দিনগুলোতে জুলুম করসেন । তিনবেলা ওটস খান চিনিছাড়া ডায়েট মিল্ক দিয়ে দুঃখটা বুঝবেন',
#  'সংবাদ পাঠিকা মেকাব নিছে',
#  'আসোলে এসব টিকেটের টাকা পাওয়া যায়না , ঐসব টিকিট কিক্রেতাদের গনপিটোনিতে মারা',
#  'বাঙালিদের মুম্বাই , মহারাষ্ট্রের খাবার ততটা ভালো লাগে । লঙ্কায় ঝাল',
#  'মহাখালীর মোড়ে একটা দোকানেও কলিজার সিঙ্গারা পাওয়া যায় । ২০১০ সালে দাম ১০ টাকা পিস',
#  'ভাল লাগার একটা এক টাকার তেহারি বিদ্যা নন্দ ধন্যবাদ মহান উদ্দোগের',
#  'বলবেন খারাপ , স্পেশাল এডিশনে ছিলামনা মাসাজ নেওয়ার জন্যই গিয়েছিলাম',
#  "100 হাত মাটির নিচে জামায়াত ইসলাম বিএনপি'র কর্মীদের পুলিশে খুঁজে বের নেয় 11 বছর ধইরা ক্যাসিনো ব্যবসা জানেনা পুলিশে সাথে রে পুলিশ জড়িত তাদেরকে আইনের আওতায় আনা",
#  'হওয়া পযর্ন্ত ভক্তভুগির পাশে আশা',
#  'ভ্রাম্যমাণ আদালত অভিযান চালিয়েছিল খাবারে ভেজাল উপস্থিতি পাওয়া গিয়েছিল খাবার খেলে নির্ঘাত কিডনির রোগে সহজেই আক্রান্ত দয়া ধরনের খাবার খাবেন',
#  'প্রেসার সময় পূজার ছুটি',
#  'বদমাশ দের বিচার সবাই জানে',
#  'তখনকার আমলে সুপারস্টার আশরাফুলকে ম্যাচ পাতানো মামলায় ভূমিকা আজকে পুলিশের খাঁচায়',
#  'আমিও রেগুলার খাই , ছোটবেলা । দুঃখজনক আমিও গন্ধযুক্ত বট পেয়েছিলাম , সম্ভবত পাঠার ছিলো । শুনলাম ঐদিন গরুর বট পায় পাঠার বট প্রিপেয়ার করেছিলো , কাস্টমারকে অর্ডারের জানায়',
#  '১০ টাকা চাঁদাবাজি পেছনে প্রশাসন দৌড়ায় । টাকা চাঁদাবাজি পেছনে দৌড়ায়',
#  'ভাই উপস্থাপনা ভালো ফেইক লাগে নিখুঁত লাগছে : ) বেস্ট অফ লাক ভাই : )',
#  'তোগো বিচারের মায়ের চুদি লোক কেমন চিনা পুলিয়ে কথা দেশে বিচার লোক দের বিচার শেক হাছিনা',
#  'বাল , এতো প্যাক প্যাক , পন্ডিতগিরির কারনেই সাভস্ক্রাইবার বেড়ে আরো কমে , মার্ক উইন্স শিখ কিভাবে খাবার রিভিউ',
#  'পশু মন খারাপ ? আজের সমাজ ব্যবসহা এতো খারাপে সময় থাকতো আবু জাহেল লজ্জা পেত',
#  'একটা কুকুরকেও এভাবে মারেনা । আহারে একটু দয়া । শুনতেই চোখে জল আসলো । কপাল পোড়া',
#  'বগুড়ার এশিয়ার মিষ্টি , দই ভিডিও চাই বস সেরা দই বগুড়ার এশিয়ার দই',
#  'বরিশালে গৌরনদী তে আসবেন এখানের দই খেয়ে যাবেন ভাইয়া',
#  'খাই দাই ডটকম খালেক সাইফুল্লাহ ভাই থাকলে আরো ভাল লাগতো',
#  'সুশিক্ষাই জাতির মেরুদন্ড',
#  'বিদেশি স্যাটেলাইট ভাড়া কথা বললে , ভাড়া বছরে মাথায় থাকতো কথা বলতেন । ২ বছরে ভাড়া দিতো বাংলাদেশ , ২ বছরের টাকা দিয়ে ১ টা স্যাটেলাইট বানানো যেতো । বুঝেছেন লাভ টা কোথায় ?',
#  'দেশের যায় যায় অবস্থা এনারা আসছে দাদাদের সোদন দেখাতে , দালালি বন্ধ দেশের বর্তমান অবস্থা গুলো ধরুন',
#  'সবাই মিলে হারি জিতি নাহি লাজ',
#  'ভাই যতটুকু সম্ভব বাংলায়ই কথা বলুন । শুনতে ভালো লাগবে',
#  'আওয়ামী লীগের ভাগ নেতাই দূর্নীতিবাজ , চরিত্রহীন , অবৈধ সম্পত্তির মালিক',
#  'অনেকের মতে , হিটলার ইহুদীগুলা হত্যা ফেললে ভালো হতো',
#  'ভাই কয়েকদিন কয়েকটা ভিডিও দেখলাম অবস্থা ছি ছি ছি',
#  '২০১৯ সালটাই আগুন দিয়ে ইয়া আল্লাহ সবাইকে হেফাযত করুন । আমিন',
#  'বাবিকে জাল খাওয়ানো',
#  'এইটা আসল খেতা পুরি ভাই : ৩',
#  'প্রতিনিয়ত খাবারের ভিডিও গুলোতে দুর যাবেন দুআা করলাম ভাইজান । আদনান ভাইয়ার অবিরাম ভালোবাসা রইলো ❤',
#  'পিছনে দুজন মুর্তি দারা করায় লাগছে',
#  'ব্যাপার টার অভাব টাই অামি কলকাতার রেস্টুরেন্ট গুলাতে বলছিলাম । অান্তরিকতাটা টের পাইছেন ? , কলকাতায় কিসের ! খাওয়ার বসার ব্যবস্হা লাগে , মিষ্টির দোকানে',
#  'কুমির খাননা আল্লাহর নাম জবেহকরা হারাম জিনিস চিকেন খাইলেন',
#  'বরঞ্চ , ইয়ান তে চলি',
#  'সিলেটী । শহরেই থাকি । খাওয়া হয়না , খাবারগুলো হাইজিনিক । ভিডিওটা ভাল লেগেছে । ধন্যবাদ',
#  'মানুষটাকে ভয় কখন জানি কালো থাবায় জীবন নাশ',
#  'সরকার উচিৎ অাইনের কাঠগড়ায় অানা',
#  'এডমিনকে অনুরোধ করব , এসব বাংলার মানুষের মাঝে সম্প্রীতি নষ্ট তৎপর ব্যান , কমেন্ট রেস্ট্রিকশনও , ঘৃণামূলক কমেন্টগুলো শো',
#  'বাঙালি ব্রেকফাস্টের সাথে ব্যাকগ্রাউন্ডে বাংলা গান ব্যাপারটা আরো জমতো',
#  'হাসির রিয়্যাক্টের অপশন কই',
#  'প্রত্যেকটায় মাদারচোদ খানকির পুলা ওগো কিসুই হইবো',
#  'বগুড়া সাত মাথা । এশিয়া , আকবরিয়া , রফাত অভাব , পাবেন',
#  'মনেহয় উপকরণ কম হয়নি , একধম ঘরোয়া',
#  'ইনশাআল্লাহ ! খোদা আপনাদের সকোল স্বপ্ন পূরণ করুক সারা জীবন আপনাদের একসাথে রাখুক আমীন',
#  'ভাবি রাষ্ট্রপতির পিছনে দাড়ানো লোক দুইজন গ্রহের প্রাণী ? এতোকিছুর হাসি কিভাবে চাপিয়ে রাখলেন গবেষণা বিষয়',
#  'ভারতের খাবার অসাধারণ । দেশে খাবার ভবিসত্তেও',
#  'তাড়াহুড়োর প্রবণতা লক্ষণীয়',
#  'ছাত্রলীগ মানেই বেজন্মা । ছাত্রলীগ মানেই কনডম ফেটে জন্মনেয়া জানোয়ার । আওমিলিগকে ভয় পাইনা । মৃত্যু একদিন হবেই',
#  'পুরিকে বিছানায় অবশেষে । এরপর কম্বল , লেপ , তোশক বালিশ পুরিও পাওয়া আশা',
#  'জমিদারের স্টাইলে কথাবার্তা ওনার সাথে',
#  'ভাইয়া আপুকে পেটুক । সত্য 2 জনেই পেটুক । পেটুক কাপল । আপুকে পেটুক চলবে',
#  'এতো গেরান্টি দিচ্ছেন কেমনে , আল্লাহর নাম , আল্লাহ কারীম চাইলে সামান্য বাতাসে চুরমার হয়ে',
#  'দাদা অসাধারন গোল বাড়ী টা দেখেন',
#  'কলকাতা আসছেন ভায়া ? আসলে আপনাকে শ্রীহরি তে কচুরি খাইতে যাব',
#  'পাপনকে সুজনকে নাননুকে তিনজনকে গ্রেফতার দরকার',
#  'বুঝায় আদনান ভাইয়ের ভিডিওই মিস । স্ক্রল নিন বিচিত্র খাবারের ব্লগ উনার চ্যানেলে',
#  'ডিসি বাল , পুরা ২৪ মিনিট দেখলাম , আসল কথা ডিসির কমড় লাড়া দেখলাম',
#  'এজন্য এগুলার ঘরে প্রতিবন্ধী কানা খোড়া বাচ্চা জন্ম সত্য',
#  'ছেলেটা একটা গান গাইছে সামাজিক ভাইলার হইছে',
#  'চাঁদা তুললে হাতিরা কেমনে বেঁচে ?',
#  'আরে জত কুলাজ্ঞার পুলিশ বাহিনী টাকার ব্যাগ ক্যামেরায় পুলিশ বলছে প্রমান পাইলে ব্যবস্তা নিবে জত চাদা বাজি',
#  '3য় পর্ব চাই , দার্জিলিং কোথাই ঘুরবো চাই',
#  'আল্লাহ গজব কোথায় ? ঈমানের দাবী সইতে পারছি',
#  'ভাগ্যিস ভাইয়া নামটাই ভুলতে নিচ্ছিলেন খাবার',
#  'দিলো কেনো ঠিকই খানেই গিয়েছিলো মামলা এখনো পারবেন',
#  'সকল বাংলাদেশি ভাই বোনদের ঈদের শুভেচ্ছা । আল্লাহ সকলের মঙ্গল করুন',
#  'খুবই ভালো জিনিস আপনারা আগ্রহ দেখাচ্ছেন । গান বাজনা হারাম । ছেলেটাকে গায়ক বানিয়ে পড়াশোনায় সাহায্য করুন , ডাক্তার চায়',
#  'ভাই আপনাকে এখনিই সাদা চুল ভালো যায় কালার ভাই ❤ ️',
#  'ছেলেটির গান শুনে হৃদয় ছুঁয়ে ভিডিওটি ভালো লেগেছে রাখার মত শুভকামনা রইল রান্না',
#  'নকলটা পড়ছে আকাশে উড়ে যেতেন',
#  'অসংখ্য ধন্যবাদ যমুনা টিভি , পরিস্থিতির সম্মুখীন হয়ে খবর প্রচারনার জন্নে',
#  'হায়দরাবাদের ফেমাস বিরিয়ানি কখন',
#  'দ্বিতীয় কমেন্ট বলছি অছাম । ধন্যবাদ । দিলে , চালাইয়া । ভালবাসা ফ্রম চাঁটগা',
#  'শ্লা আরো নিউজ চাই , আপনারা সাংবাদিকরাই চাইলে শয়তানকে জেলে পাঠাতে',
#  'টাকা লোকটাকে লটারির মাইকিং ২০২০ গন পিটুনি দিয়ে মারা',
#  'খাবার গুলো এঁটো রাখছেন ? এঁটো খাবার গুলো খায় ? ভালো , একটা পেলেট পরিমাণ খাবেন ততটা চামচে । এটাতে ভালো লাগে',
#  'একমাএ মহাবিপদ পৃথিবীকে রক্ষা',
#  'ধন্যবাদ ভাইয়া । নাম ইয়ালিদ , ওয়ালিদ',
#  'ব্যাকগ্রাউন্ড মিউজিক বাংলায় আরো আকর্ষণীয় লাগবে । আপন লাগবে',
#  'জিন্দা মুরগি মরা মুরগি খান ভাই',
#  'জেলের বাহিরে চোরের লোক',
#  'প্রধানকে হোল নাটক , হায়রে দেশ',
#  'ভাই মনেহয় কষা',
#  'আসলে বাংলাদেশের পলিশ কুত্তারা নাম্বার ওয়ান জংগী',
#  'পেটের ক্ষুধায় চুরি । চোরের হাত , রাজ্যের বাদশাহর হাত কেটে দেয়া । হযরত আলী ( রাঃ )',
#  'পদ্মার পাড়ে , পুঁটি মাছ , দোস্ত আদনানের বাবায় । লাল শাড়ির সারি , বালু চরের মেলায়',
#  'এইটা হিন্দু বোর্ডিং হোটেল দাদা । দেশে এইরকম হোটেল । বিউটি বোর্ডিং প্রখ্যাত ঢাকায়',
#  'সাধারন মানুষের পিবিআই 0 । 1 % সাহায্য',
#  'কাবাব কেল্লায় হারিয়ে গিয়েছি',
#  'লুকিয়ে টানা সিগারেট',
#  'ক্যামেরায় চেহারা দেখালে কাস্টমার পাবি নটির দল = = = = =',
#  'দই তৈরীর পর্দতিটা দেখালে ভালো হতো',
#  'রাতের বেলাও এইসবগুলো পাবো',
#  'বাংলাদেশে আসেন কাচ্চি খাওয়াবো',
#  'প্রশ্নের সাথে উত্তরের মিল পাইলাম',
#  'গ্যাস , ডায়রিয়া , পাইলস কোনোটাই ? ভাজা পোড়া খান খালেদ সাইফুল্লাহ',
#  'ভাই , ভাল লাগলো , খেতে ভালবাসেন তেমনি আমিও খেতে ভালবাসি । আজকের আইটেম মুখরোচক । আজকেই অনুষ্ঠানটি দেখছি । দেখার সাথে সাথেই সাবস্ক্রাইব করছি । , বলেছি খেতে পছন্দ । হাহাহাহাহাহাহা',
#  'হালারপুতরে আবালদের',
#  'ভাইয়া , ডিটেল প্ল্যান জানলে খরচের কথা জায়া',
#  'অবশেষে প্রাক্তন প্রেসিডেন্ট মরহুম হোসাইন মোহাম্মদ এরশাদের বিজয় । সময়ের দাবি',
#  'ভাই ওনি ১৭ বছর যাবৎ জায়গায় খাবার বিক্রি । ওনি জানেন অন্যান্য হোটেলে নেয়',
#  'পরবর্তী পর্বে আসা কেরানীগঞ্জ ইনসার আলীর খুদের ভাকাটা খেয়ে দেখবেন',
#  'খাবার হোটেলগুলো তে কেমন তেহারি খাই সন্দেহ',
#  ', রাখে আল্লাহ মারে , আল্লাহ হোয়াকবার',
#  'হেঁরে তুই শালা একদম কাঁদবিনা',
#  'ধন্যবাদ পুলিশ সুপার সুপার সপ সপন',
#  'ভাইয়া পেইজের ইনবক্সে নাম্বার চেয়ে একটা মেসেজ পাঠিয়েছি',
#  'ভাই ঢাকা হাইজ সাজেক পারবো',
#  'পুলিশগুলোকে ঠিকমতো ডিম থেরাপি',
#  'আচ্ছা ভাইয়া 2শত ডলার কতো রুপি পাবো । প্লিজ জানাবেন',
#  'বাংলাদেশের ধানমন্ডিতে কয়েকটা বুফে রেস্টুরেন্ট টোকেন বিল পে স্ন্যাক্স খেয়ে বাইরে কিছুক্ষণ ঘুরে ডিনার লাঞ্চ যায় । সিস্টেম',
#  'বুইড়া ধামরা , ! আবাল । খাওয়া ছাড়া বাল ! ?',
#  'কালা খাট্টা বাংলাদেশে পাওয়া যায়না',
#  'জানোয়ার বাচ্ছাকে আইনের আওতায় আনা',
#  'গরিব লোকটার টাকাটা পাইয়ে দিলে দোয়া পাবেন',
#  'প্রথমেই খাওয়ায় দেয় বুফে খেতে !',
#  'বাল , ছেয়ে বড় বড় শিল্পী ভাত খেতে ভাত পাইনা , বাংলাদেশ , দুদিন ধীরেধীরে হাড়িয়ে যাই সবাই',
#  'বাংলাদেশে সবকিছুই , গোপনে । আসলেই গোপনে ? নেটওয়ার্ক এতো বিস্তৃত',
#  'শোনে রাখ টাইগার তোকে ভালোবাসি',
#  'মালাউনদের মুখের ভাষা অংশেই কম',
#  'সপ্ন দিয়ে বাচ্চার ভবিষ্যৎ , সাথে ধন্যবাদ পুলিশ অফিসার জাহিদুল ❤ , প্রমান `` মানবতা `` বলেই এখনো বেচে আছি , `` মানুষ মানুশের `` , আবারো প্রমান',
#  'বাংলাদেশের অচল বিচার রাজনিতির',
#  'ঢাকায় একটা প্রবাদ আ্ছে খাইতে খাইতে কাইত হইছে অবস্থা কাইত হয়ে গেছেন',
#  'বাহ চমৎকার ! দেশের নিউজ রিপোর্টার গুলো , কই কোনোদিন দেখলাম বস্তিতে , ফুর্টপাতে , স্টেশনে রাত পার করতেছে , মানুষ খেয়ে খুদার যন্তনায় ছটফট করতেছে জীবনকথা ধরতে ! বাংলাদেশ টা ইন্ডিয়ার বিক্রি হয়ে',
#  'ধন্যবাদ , আদনান ভাই ❤ ️হ্যাপি ফুডিং ❤ ️',
#  'মুসলিম , সংগ্রামি , চির রণবীর । আল্লাহকে কাওকে মানি , নারায়ে তাকবীর । নারায়ে তাকবীর , নারায়ে তাকবীর',
#  'মাছের দাম একটু বেশী এখানকার',
#  'সাইম ভাই বর্ডারে কি★ পুট লাগে ★',
#  'কিছুর মালিক ঔ এক আল্লাহ ইয়া আল্লাহ যেনো হুকুম আহকাম মেনে চলতে তওফিক দাও আমিন',
#  'যমুনা টেলিভিশনের নিজস্ব আন্দোলনের সবাই গরীর লোকটাকে পাওনা ফিরেপেতে চাই',
#  'ভাইয়া রেস্টুরেন্টা কোথায়',
#  'রেজেলার নাম শুনলে মুখে জল আসে',
#  'খাসির রেজালাটা দেখতেই অসাধারণ',
#  'খাইতে খাইতে চুল * ল পাইকা',
#  'দয়া দামী দামী রেষ্টুরেন্টে মানের রেষ্টুরেন্টেে ভিডিও করুন',
#  'ছাত্রলীগকে জানোয়ারলীগ হিসেবে ঘোষনা দিয়ে নিষিদ্ধ',
#  'ভাল লিরিকও সাথে এড । থিমটা বড় , ছন্দে । মনোটোনাসও হওয়া । শুনে বোর ফিল',
#  'ভাই আপনাকে অসংখ্য ধন্নবাদ । লাস্ট উইক দারজিলিং ঘুরে আসলাম , ভিডিও গুলো , উপকার হইসে । শিলং - চেরাপুঞ্জি নিয়া ভিডিও চাই',
#  'বর্তমান সরকারের আমলে এরকম অসাধারণ সুন্দর পদক্ষেপে মুগ্ধ হচ্ছি',
#  'ভাইয়া রাব্বির তন্ময় ভাইয়া সিনিয়রদের নার্ভাস ফিল ভিডিওতে',
#  'ভিডিওটা ভালো লাগছে এসব ভিডিও হেটার',
#  'দাদা কলকাতায় আসা',
#  'সোনার বাংলাকে সন্ত্রাসী বাংলায় পরিনত করছে\u200c শুয়ারের বাচ্চা পুলিশেরা',
#  'এজন্য আপনাকে বগুড়াই আসতে আপনাকে স্থানীয়বাসির সাহায্য , অভিজ্ঞ । ভিডিও ভাল লেগেছে',
#  'বুয়েট টিম 360 অনুসন্ধানের ভিডিও দিলে আরো বেরিয়ে আসবে , একটা ভিডিও চাই',
#  'প্রথমত আজকে রোজা রেখেছি',
#  'প্রতিদিন সেক্স পুশআপ স্টাইল মেদ ভুরি থাকবেনা',
#  'ভারতের সবগুলো রাজ্যের ঐতিহ্যবাহি বৈচিত্র্যময় খাবারগুলো কভার ভালো',
#  'সদরঘাট পাটুয়টুলীর কাশ্মীর কাচ্চি ঘরের ফুড রিভিউ চাই',
#  'বিশ্বাস এলাকা খোজ দেখেন । । ছেলেদের চাকরিও দেননি । ভালো শিক্ষা প্রতিষ্ঠান পারতেন',
#  'লোকমান স্যারকে চিনি ফেমেলি সম্পর্কে জানি হয়না মধ্য পান । কারোন বাসায় দিনের চলা ফেরা ছিলো',
#  'যেহেতু সাভার স্টার । ঢাকাতে যাবার সময় আপাতত',
#  'গো মুত্র খাও ।',
#  "চ্যাংড়াবান্দা হয়ে শিলিগুড়ি দাজি ' লিং ভিডিওটা দারুণ লাগল । দেখান বলার ভংগিটাও প্রশংশনিয়",
#  'দ্রব্যমূল্যের উর্ধ্বগতির সময়ে এক টাকার সিঙাড়া ।',
#  'বিউটি পারলার রেড ঘরে ঘড়্রে পতিতালয়',
#  'কেন্সার হাস্পাতালের লটারির গাড়ি',
#  'ওরে ভাই , ভিডিও দেখার অপেক্ষায় ছিলাম কয়েকদিন চ্যানেল চেক করতাম ভিডিও আপলোড দিয়েছেন কিনা বরাবরঈ হতাশ যাক মাঝে এসছেন আলহামদুলিল্লাহ্\u200c',
#  'বাহ , দারুণ ! ফেভারিট ফুড ব্লগাররা সবাই একসাথে',
#  'হিল্লোল ভাই প্রতিটি ভিডিও উপকারি । দেশের বাইরে',
#  'এগিয়ে জাও রানা দোয়া ভালোবাসা দুনটাই আচে♥♥♥',
#  'পুলিশদের দোষের মানুষের হাতে মারা যায়',
#  "জিভ , খাদ্য । জিভে একেবারে চোখ পাকিয়ে জঘন্য ফেলার হয়নি , ইতস্তত ' ' বলার লেগেছে",
#  'ভাগাড়ে জন্মাইসো খবরে দরকার । কোলকাতার ভাগাড়ের মাংস খায়া ঢেকুর তুলতে তুলতে ভাগাড়েই পাছা উল্টায়ে পড়ে থাক',
#  'সা\u200cথে কিভা\u200cবে যোগা\u200cযোগ কর\u200cতে পা\u200cরি ? রী\u200cতিমত একজন ভক্ত হ\u200cয়ে গে\u200cছি',
#  'নওসিন আন্টি বানিয়ে ফেলতে সেন খাওয়াবেন',
#  'ভাই খালি খাইয়েনা , ডায়েটকন্ট্রোল কইরেন হা হা হা',
#  'কক্সবাজারের মানুষ বিরিয়ানি মানেই জানে । পোলাও সাথে আলাদা মাংস দিয়ে সেটাকে বিরিয়ানি চালিয়ে দেয় । শেষ গিয়েছিলাম রীতিমত অবাক । কক্সবাজার মাছ শুটকি ভর্তা সী ফুড জন্যই বেষ্ট । বিরিয়ানি নিলে হতাশ',
#  'বাহ ! বোটের , আপনারা সিঁড়িতে ? ভালো লাগলো জেনে : )',
#  'আচ্ছা ইডেনের একদম',
#  'বিদেশী দেশে । এদেশে কম সবাই যানে । পুলিশ জায়গাএকি ভুমিকা পালন',
#  'ভিডিওটা আরেকবার দেখেুন বুঝতে পারবেন নিশ্চই',
#  'প্লাইটে , ভিসা লাগানোর সময় উল্লেখ',
#  'রাসূল ( সাঃ ) , খাবারের শুরুতে বিসমিল্লাহ , খাবার হারাম , শয়তানের হালাল হয়ে যায়',
#  'সাবস্ক্রাইবারসদের মিস্টি খাওয়াবেন ভাইয়া',
#  'বাহিনীতে অযোগ্য অদখ্য লোক বাহিনী ততটাই দুর্নীতি গ্রস্ত',
#  'লটারি জেতার টাকা দেয় অজুহাত দেখাল সময় শেষ হয়ে লটারি ছাড়তেছে সরকারের নিয়ন্ত্রণে ? বাংলার মাটিতে কিভাবে জিন্দা',
#  'ভাই সবগুলো ভিডিও সুন্দর , দার্জিলিং যাচ্ছি 21 / 10 / 2019 , ভাই ওইখানে শীত , ওইখান কলকাতা যাবো',
#  'সৌরভ গাঙ্গলিকে পছন্দ একটা লাইক দিবেন , অপছন্দ করেণনা একটা কমেন্ট',
#  'আশাকরি যমুনা টিভির সহায়তায় লোকটা টাকা পাবে + 360 ড্রিগ্রি টিমকে পাঠানো',
#  'পিছনের অংেশ মটু টারে ভাল লাগছে',
#  'যেই ভাব খাইলেন হইতেছে জীবনে হইতেছে মজার খাবার খাননি',
#  'আল্লাহ ভিপি নুরকে জনগণের বাঁচিয়ে রাখুন , সকল ক্ষমতাসীনদের জবাবদিহিতার , সঠিক সমালোচনা । ক্ষমতা , প্রশাসন দিয়ে , ভাবতে',
#  'ভাই উচ্চারণটা চট্টলা , চট্টগ্রামের উচ্চারণের মত চট্রলা ভাইয়া',
#  'সবদের ধিক্কার জানাই ইট দিয়ে ঢেল দিচ্ছিল কারণেই । অার , অাটক করেছিল তারাও এক প্রকার অপরাধী',
#  'ডক্টর বানান টাও জানে',
#  'খানকির পোলাগোরে কুকুর দিয়ে ছোদান দরকার',
#  'একটা বাচ্চা র\u200d্যাপার টিভিতে প্রতিবেদন দেখাচ্ছে । । কাম । কুকুরের রাস্তায় হাগার সেটার লাইভ সময়ের দাবি',
#  'বাড়ির পাশে রেস্টুরেন্টটা দেখেছি পাহাড়ি খাবার পাওয়া যায় বুঝতে পারিনি । কর্তৃপক্ষ স্থানীয়ভাবে আরো মার্কেটিং চালায়',
#  'কামালের মামার বিরাণী টা ভালো',
#  'হায়রে বাঙ্গালী । ভাই , একটা বড় ভুল ধরিয়ে ডিমটিভেট বলার । ভিডিও সম্পরকে খারাপ বলি উল্টা লাইক দিসি । একজন সেলেব্রিটি একটা প্রোজেক্ট নামসে , প্রফেশনালিটি থাকাটা চোখে লাগে',
#  'ধর্মান্ধ সাম্যবাদের',
#  'ভাইয়া পেট ব্যাথা করেনা ? জেভাবে খাবার খান দেখেতো জিভে জল এসেপরে',
#  'বাংলাদেশে টেলেন্টের অভাব সাপোর্টের',
#  'ভূল মানুষেই সংশোধন মানুষেই , ৭ ৩ ২ = ১২ ১১ ফেলছে হইছে ? আবালের লাফাইয়া কইরা দেখুন কেমন লাগে',
#  'দাদা বাংলাদেশে পায়েসকে ফিরনী',
#  'সবগুলা প্রিয় মানুষকে একসাথে পেয়ে ভালো লাগলো',
#  'ছাত্রলীগের সবাই খারাপ । তোরা সবাই ছাত্রলীগ কথা বলচ',
#  'ইন্টারনেট কম্পিউটার চালানোর বিদ্যুৎ বিল বাবদ মাসে খরচ',
#  'লাইনটা অর্থ বহন',
#  'বিরিয়ানি হাউসটা লালবাগে পাবেন',
#  'শহরের অলিগলির খবর',
#  'ফাহিম ভাই বাড়ি রাজশাহী ? অর এনি লিংক উইদ রাজশাহী',
#  'একজন আবালের মত লাফাইছে , আরেকজন সাথে সাথে বলদের মত হাম্বা হাম্বা',
#  'হাইকোর্ট বললে ভুল টিম 360 ড্রিগ্রীর অনুসন্ধান দেখবেন সিরাজগঞ্জের জিল হোসেনের গ্রেজুয়েসন , রায় থাকলেও মানতে নারাজ বাদী পক্ষ',
#  '\u200bযারা রাষ্ট্র বিরোধি স্ট্যাটাস সবাইকে আবরারের হত্যা উচিৎ',
#  'মাইক্রো । 4500 রুপির পড়বে',
#  'গরীব মানুষের হক্ব এভাবে মেরে দেয়া বিচার । অবশ্যই বিচারের আওতায় আনা । সাথে একমত লাইক',
#  'বাংলাই একটা প্রবাদ শুয়ুরে চিনে কচু গেচু আইফোন ফোন',
#  'ধন্যবাদ দাদা । আপনাদের কোলকাতা 5 / 7 ফিরলাম : )',
#  'ধন্যবাদ আপনাকে উৎসাহিত , দোয়া',
#  'বাংলাদেশের সবচেয়ে বড় জলপ্রপাত আসুন এলাকায় বড়লেখা উপজেলায় অবস্তিত আসতে গাঈড করব ভাই টিকিট কতো টাকা হইছিলো ভাই বিমানের প্লিজ রিপ্লে চাই',
#  'ভাবলাম মাছের রিভিউ টা মিস করছি ভিডিও দুইবার দেখলাম',
#  'মাগীবাজ লীগ । মায়ের পুটকী দিয়ে বের হইছে ভারতের মা কেও চুদতে । খানকীর বাচ্চা । জারজ শুওর মাদারচোদ',
#  'এক সন্তাস আরোক পুলিশ',
#  'এইখানে ভালো ছেলেরা পড়াশোনা কিভাবে । যন্তনা । বেবস্হা নিলে আরো ভয়ংকর কিজে । একমাত্র আল্লাহ ছাড়া যানে',
#  'কাজের প্যাশনেট থাকলে কিভাবে সফল হওয়া যায় আদনান ভাই উজ্জ্বল প্রমান , অনুপ্রেরণা । ❤ ️কলকাতা',
#  'হাটার সিস্টেম',
#  'একটাও মাণষের চোদা',
#  'আনকম একটা খানা , অ\u200cনেক শুক\u200cরিয়া ভি\u200cডিওর',
#  'মাহমুদ ভাইয়া ধন্যবাদ । প্রতিভা আনার',
#  'আচ্ছা ভাই যায়গার লোকেশন টা বলবেন',
#  'প্রতিটা ভিডিও তেই আপননি ইনফোর্মেশন দিয়ে , ব্যাপার টা ভালো লাগে',
#  'হে মহান আল্লাহ , সৃষ্টি করেছ । দয়া , বনের আগুন নিভিয়ে দাও বনের পশু-পাখিদের রক্ষা করো । আমিন',
#  'আমিও সেম রেখেছি ক্যামেরার হয়তো মাথায় আসতো',
#  'সম্ভব , পথ টা রিস্কি । যাওয়াই ভালো',
#  '* নাগা খেলেই চোখে পানি *',
#  'ব্যামের , আপনাকে দৌড় ঝাপ ঘামায়',
#  'কাজী ফুড আইল্যান্ড উত্তরাতে এসেছে',
#  ', তগো পোলা মাইয়া গাড়ির তলে মরবো',
#  'পরিস্কারমনে । ভালো লেগেছে',
#  'ডাল অাছে চাপটি কিভাবে , দোসা',
#  'মেঘ চাইলে বর্ষাকাল , কাঞ্চনজঙ্ঘা চাইলে শীতকাল বরফ চাইলে ডিসেম্বার',
#  'নাম্বারে কল দিয়েছিলেন ? 01844016194 - নাম্বারের কল দিয়েন প্লিজ',
#  'প্রধানমন্ত্রী শেখহাসিনা কুত্তাগুলারে এতটাকা বেতন দেয় পরও সাউয়া ভরেনা',
#  'ছাত্রসমাজ জিন্দাবাদ',
#  "আরে ভাই এগুলা বাদ , বাংলাদেশের একটু এভাবে নজর প্লিজ '' '' বাংলাদেশের বন্যার কারনে মানুস ঘর বাড়ি হারিয়েছে , প্রতিবেদন , সবাই সাহায্য",
#  'তোমরা উটের মুত খাইয়াও বালটা বানাইতে পারলা । গরুর মুত খেয়েও তোমাদের গুনে এগিয়ে',
#  'রাজশাহী বলছি , রাজশাহী শহরটা কেমন লাগলো খাবারের সাথে সাথে',
#  'শ্যামলী শিলিগুড়ি যায়',
#  'সারা দে\u200cশে থে\u200cকে অডার যা\u200cবে কুল\u200cফি',
#  'দিচ্ছে ভাই ? ফুড রিভিও যেহেতু দিচ্ছে জেনে বলুন',
#  'আজব , একটা মানুষকে পিটুনিতে হত্যা হয়েছে 3 গন্টা দরে , সিকোরিটি , শিক্ষক কোথায় ছিলো কানে লাঠির আওয়াজ যায়না , আরে পাশের রুমের লোকরা ধফাধফি শুনেনা , আসলে মানুষ অন্ধ সেজে , ভূলে যাই',
#  'পুরো রেস্টুরেন্ট ফাঁকা',
#  'ওনেক ভালো লাগে ভাইয়া খাবারের ভিডিও গুলো',
#  'বাই রোডে ট্রানজিট ভিসা লাগবে',
#  'ট্রাম্প , কিম , মোদির মত শাসকরা পৃথিবীর লজ্জা',
#  'ক্যামেরাম্যান বে রসিক মেয়েটার বান্ধবি হয়তো বে রসিক',
#  'ব্রেকফাস্টকে নাশ্\u200cতা নাস্তা থাকি , আপনারা সকালের খাবার জলখাবার । এগুলি চয়েস । ভুল , সবই',
#  'বৃহস্পতিবার দেবার ট্রাই করছি',
#  'জংগী আসলো কোথায় , আবাল পোষ্ট',
#  'আল্লারে এইগুলো দেখলাম ? আমিতো পাগল হয়ে গেলাম । ওরে আল্লাহ করল ? বুয়েটের অবস্থা ? হায় আল্লাহ আওয়ামেলিগ ধংস কর । বলার জায়গা পাচ্ছি',
#  'ভাই মিষ্টিজাতীয় খাবার দোকানের রিভিও দেবেন প্লিজ',
#  'অর্থাৎ এডড্রেস এড শব্দটি বাদ দিয়েছেন',
#  'মাছের রাজা ইলিশ দেশের রাজা পুলিশ জারাই শতশত্রু পথেই আছেন পতি বাদ । মরে জান পোশাক দেশটাকে কলংক মুক্তি । জারা দেশটাকে শাদিন তাদেরকে অশন মানি',
#  'শুটিং সময় নয়েজ কান্সেলেশন মাইক্রোফোন । প্রচুর নয়েজ',
#  'এইখানে ভালো ছেলেরা পড়াশোনা কিভাবে । যন্তনা । বেবস্হা নিলে আরো ভয়ংকর কিজে । একমাত্র আল্লাহ ছাড়া যানে',
#  'এজন্য এগুলার ঘরে প্রতিবন্ধী কানা খোড়া বাচ্চা জন্ম সত্য',
#  'দোয়া ৱানা এক বড়ো',
#  'খাবার হাত গুটিয়ে থাকার পাবলিক হিল্লোল ভাই হাহাহাহা যাহোক ভালো সবাই বেশী বেশী খাবেন',
#  ', সেগুলোতে রিপোর্ট সংগ্রহ',
#  'ভাই পাঠাও অর্ডার কারা যায়',
#  'সাজেক পাহাড়েত ভাফ গাড়ি উটে',
#  'হেতের বিচার পুলিশে করলেও রাতে হেতের বৌয়ে ঠিকই করবো',
#  'স্যার ধন্যবাদ উৎসাহ মূলক বক্তব্যের',
#  'কলকাতার বাঙালীদের মন জয় নিয়েছেন , সন্দেহ',
#  'সেলুট জানাই ভিপি নুরু ভাইয়ের মত সিংহকে , আল্লাহ তাআলা নূর ভাইকে নেক হায়াত দান করুক',
#  'সারাজীবন ইচ্ছা মত টাকা কামাইছো',
#  'বাংলাদেশের টিভি চেনেল । খবর চুদাও রেন্ডিয়ার । কুত্তার বাচ্চা যমুনা টিভিকে সবাই বয়কট করুন',
#  'ভাই যেখানের যাই খান টাংগাইলে ভরসা খাইতে যাবেন তাইলে পুরাই ঠকবেন',
#  'দন্যবাদ পুলিশ অফিসার সেইসাথে স্বপনকে',
#  'ওয়ার্ল্ডের বড় বড় ট্র্যাভেলারদের ফুড রেসিপি দেখছি তোর মত কুত্তার বাচ্চা দেখি । ভদ্র ভাষায় কথা বলার ধৈর্য হারিয়ে ফেলছি তোর এরকম আচরণে । তোর আচরণ মানুষকে বিরক্ত কনো মানে',
#  'স্পা চুদাচুদির জায়গা । টাকা দিয়ে মাগি ভাড়া বড়লোক চোদারুরা',
#  '* অবশেষে দীর্ঘ দিনের নারকীয় তান্ডব মুক্তি পেল হাতি । সাধুবাদ জানাই র\u200d্যাবের মহৎ উদ্যোগ । *',
#  'শাপলা চত্তরে গেলেই একটা ব্যবস্থা হয়ে',
#  'আজকের খাবার টা জমে নি । আদনান ভাই বহুত হইসে , দেশে আসেন , এদেশেই মান সম্মত খাবার । আজাইরা খাবার',
#  'সারা বছর অভিযান চালিয়ে লাভ বাঙ্গালী',
#  'মন খারাপ সমস্যা , সায়েম ভাইয়ের ভিডিও । ব্যাস ভালোলাগা , অসং্খ্য ধন্যবাদ ভাই',
#  'মাগির পোলা তোর ফুটানি , খাংকির পোলা তোরে চিনি , তোর বউরে একটু চিনি দিক দিয়ে , ঝাল চোদাও',
#  'গর্জে বর্ষে , অতীতে প্রমান পেয়ে আসছি',
#  'ইনশাআল্লাহ আগামীর রাষ্ট্র নায়ক নুর ভাই',
#  'বগুড়ার সোনাতলার বিখ্যাত স্মরণিকার দই ট্রাই করেছিলাম , বেস্ট লেগেছে',
#  'পিবিআই চোর - পুলিশের গালে জুতা মারো তালে তালে',
#  'ছোট মাছের টক , ঝোলটার টেষ্ট জীবনে খাওয়া শ্রেষ্ঠ মাছ , প্রথমে ছোট মাছ খেতে চাইনি খেয়ে আহহ অমৃত',
#  '- প্রিয় রেস্টুরেন্ট । খাবার মজ্জা , ডেকোরেশন । ❤',
#  'পেটের নিজ পায়ের তালা স্টাম দিয়ে পিটিয়ে স্টাম ভেঙে ফেলে',
#  'ব্যাক্তিগত সৌরভদা চিনি কয়েকবার দেখেছি ; পিসতুতো ভাইয়ের সৌরভদার বন্ধুত্ব',
#  'খাই দাই ডট কমের ভিডিও দিচ্ছেন খালিদ ভাই',
#  '? বিকেলে গিয়েই পেলাম',
#  'বাংলাদেশের জনপ্রিয় একজন নাট্যাভিনেতা । শখ বানানো ভিডিওগুলিতে কটু মন্তব্য বাংলার মানুষের মাঝে প্যাঁচ লাগানোর । মন মস্তিষ্কের ক্ষুদ্রতাই প্রকাশ',
#  'পরিবেশ খুবই নোংরামি । ছেলে মেয়েরা জড়ায়া । ফ্যামিলি খুবই লজ্জাজনক',
#  'দেখলাম মাশরাফির বাড়ি মোস্তাফিজের বাড়ি দেখাতে । গরীব মোস্তাফিজের বাড়ি দেখায়',
#  'গুলা চ্যানেলই বেল বাটন চাপা',
#  'ভাইয়া ফারিয়ার হাশি টা সুন্দর',
#  'ওটা ঝোল স্টু',
#  'টঙ্গীর ঐতিহ্য মালেকের হোটেল',
#  'পাসপোর্ট থাকলেই ? প্রতিজন খরচ',
#  'পুরান ঢাকার সিরিজই',
#  'প্রত্যেক কলেজে লোমহর্ষক ঘটনা ঘটে নিন্দনীয় , ব্যপারে সরকারের সুখ্য অনুসন্ধানের মাননীয় প্রধানমন্ত্রীর দৃষ্টি আর্কষন করছি',
#  'তুই ধাক্কা ছাডা শব্দ চিনস',
#  'ভিডিওটা গুছানো ছিলো । রান্নাঘরটাও পরিস্কার । শেয়ার ধন্যবাদ',
#  'ওহ ব্রো মজা কমেন্ট বক্সে.',
#  'বাংলাদেশের নিউজ চেনাল সাবস্ক্রাইব তারপরও নিউজটা সাবস্ক্রাইব করলাম যমুনা টিভি',
#  'ভাইয়েরা অযথা উস্কানিমূলক কথা বাংলার সম্প্রীতি নষ্ট , উদ্দেশ্যে বলছি ; ভাই মরিস , একটু দূরে মর',
#  'ভাই ভিডিও এক বসায় ফেলসি , ভিডিও তোহ দেখেছি । অসাধারণ ভাইয়া অসাধারণ । পেটুক ভাবীকে সালাম তরফ',
#  'নস্টের পথে এক দাপ এগিয়ে , কারন হিপহপ গাজাও চিনতাই চাদাবাজি চাডা উপায়',
#  'হযরত সায়্যিদুনা আনাস বিন মালিক রাদিয়াল্লাহু তাআলা আনহু ইরশাদ , নবী করীম সাল্লাল্লাহু আলাইহি ওয়াসাল্লাম দাঁড়িয়ে পান আহার নিষেধ',
#  'ভিডিও দেখি খাওয়ার প্ল্যান , ভাই শো ছাড়ার বইলেন , জায়গাটা নিবো , সারাদিন প্রোডিউচার খাবো',
#  'ভাই , সত্য বললে বিপদ আসবেই , পিছুপা হওয়া । , এগিয়ে , আল্লাহ সাথে , ,',
#  'পিটের চামড়া তোলা',
#  'পাপনকে গেরাপতার হক বেরেয়ে আসবে',
#  'যতবেশি ধর্মের কচকচানি ভারত বিদ্বেষ ছড়াবেন , ততই লাত্থি উষ্টা খেতে',
#  'ভাই জানেন ? অসম্ভব মিশুক একজন মানুষ',
#  'মাইক্রোফোন ভাইয়া ! কষ্ট ভিডিও টা দেখার ধন্যবাদ ভাইয়া :',
#  'বেগুনের অাচারটা দারুন বানায়',
#  'ভাইয়া ভিডিওটা ভালো লেগেছে সাথে মহিলাটা গেলেন কথা',
#  'অতিরিক্ত গাজা সেবন করেও পানিতে নাইমা সাতার কাটা যায়',
#  'সম্পর্ক গড়ালে বিয়ের ভাইয়া বন্ধ',
#  '৫ টাকা ডিসকাউন্ট দেয়ার বিষয়টা সত্যিই বিব্রতকর',
#  'কম টাকায় খাওয়া য়ায় ভাই জানতা',
#  'ওহ ! অপেক্ষায় ধৈর্যের পরীক্ষা নিলেন । ইনফরমেটিভ প্রতিটা পর্ব । শেষ পর্বটার আপেক্ষায় রইলাম । মাসের শেষে দার্জিলিং যাবার ইচ্ছা । ভিডিও গুলো গাইড হিসেবে । অসংখ্য ধন্যবাদ কষ্ট',
#  'দুঃখ একটাই কিডনি বেচেও কিনতে পারলাম',
#  "নান্না ' কাচ্চি বেস্ট লাগে ; সুলতান ' স ডাইন । তবেও কোনটার কোনটাকে ভালো বলব । ভালো লাগাটা আপেক্ষিক বিষয়",
#  'ভাইয়া বাংলাবাজারের ক্যাফে কর্নারের বিখ্যাত খাসির ক্রামচাপ প্রোগ্রাম বানাবেন',
#  'তদন্তের আশায় বাংলাদেশের মানুষ স্বপ্ন বিচার , আসলেই বিচার',
#  'বুঝে ২ ২০ ডলার সহায়তা গ্রহণ করেনি । ভেবেছে উন্নত কান্ট্রি আমাজনকে অর্থ দিচ্ছে',
#  'মাসুদ রানা প্রতিযোগিতা চারম হাসির ডাবিং । দেখলে চরম মিস',
#  'ভিডিওটা সুন্দরর',
#  'কথা টাকা যাই কিভাবে ভাংগাবো পারবো । প্লিজ জানাবেন',
#  'স্ট্রীট ফুড একটা সিরিজ ভালো হয়✌',
#  'খানকির পোলারা আকাম চুদাইবো জয় বাংলা স্লোগান সবকিছু পার যাইবো',
#  '180 টা আবালা ডিজলাইক দিয়া প্রমাণ চাইলো',
#  'ভিডিও ৩ মিনিট সমস্যা',
#  'অল্প সময়ে হয়তো পারবো ভুইয়ার ফুল ব্যাকাপ পাপন । একটা কথা কঠিন সত্য পাপ বাপকেও ছারেনা',
#  'ডারজেলিং যাবো । আসা',
#  'আজকের উপস্থাপনা মেনুগুলো খাবার ভাল ধন্যবাদ',
#  'বাংলাদেশের 33 ব্যাংকের ইন্টারনেট ব্যাংকিং পারবেন অ্যাপস , অ্যাপস প্লে স্টোর ডাউনলোড লিংকে ক্লিক করুন :',
#  'ওয়াও ! রোম্যান্টিক',
#  'দেশের শ্রেষ্ট চোর পুলিশ',
#  'সত্তি একটা বিরল অভিঙ্গতা । ধন্যবাদ আদনান ভাই । বোরহাণীর রেসেপিটা দেখালে উপকৃত হতাম',
#  'ভদ্র ভালো উন্নত জাতি , বিদেশী আপরাধীদের চোলে দেই',
#  "বস এগিয়ে আরো আছি সময় ' / বানিজ্য মেলা ভিডিও বানাই",
#  '33 নিয়ম 1 খরচায় ন্যায় বিচার নিশ্চিত আদালতকে নির্দেশ দিয়েছে আইন । বাংলাদেশের',
#  'পুলিশ অফিসার জাহিদ ভাই আপনাকে । স্যালুট তানিম ভাই ধন্যবাদ জানাই । এক টা ভাষা । আল্লাহ পৃথিবীর । দুনিয়া ভালো লোক বলেই পৃথিবী রয়েছে',
#  'আসলেই গান টা ভালো হয়েছে৷',
#  'ভাই একটু খাই পরোটাই খেয়ে নিলেন',
#  'বাংলাদেশিরা খাবার যেটাতে পেয়াজ করিনা । পেয়াজ লাগেই । পেয়াজ ছাড়া অচল',
#  'ছাত্রের সাংবাদিক গুয়াই মারা ভিপি নুরুর',
#  'ভাইয়া উত্তরবঙ্গের বগুড়া শহরে কালিতলা শিববাটি বাজারের ভিতরে রামের চপ কাকলেট পাওয়া যায় । দোকানের মালিক রাম বাবু । খাসীর মাংসের চপ কাকলেট দাম ৫ টাকা',
#  '2015 সালে বের হইছে । বাইক',
#  'রানা আরো লাখ লাখ শিশুর প্রতিবিম্ব',
#  'ভারতে আসার অসংখ্য ধন্যবাদ',
#  'পুলিশ ভাইটার অবাধান বেশী , স্বপ্নকেও ধন্যবাদ',
#  'দুর্গের পতন ঘটালেন',
#  'আপনাকে সবাই অনুসরণ হিল্লোল ভাইয়া ড্রেস আপ টা অনুসরণ নি । সিনিয়র একজন মানুষ হাফপ্যান্ট পড়ে ক্যামেরার দাঁড়ানো সত্যি অদ্ভুত লেগেছে',
#  'রানা হারা বছর সেহরি ছাড়া রোজা',
#  'দেশটাকে ধ্বংস ফালাইছে পুলিশ রা',
#  'আসুন , রাষ্ট্রকে বলি , বাল ফালাইয়া পাশে দাঁড়াও ।',
#  'মাগীর পুলা , বাডপারে দেশ বাংলাদেশ',
#  'আমারতো পুরা ব্যাপারটা ভূয়া , সুপার ফ্লপ যাই বানাক',
#  'দুষ্টু পুলিশ বাংলাদেশের অাইন শৃঙ্খলা অভনতির মূল নাটের গুরু',
#  'ভ্লগ ভাল লাগে নাটকে আপনাকে একটা দেখিনা',
#  'খাবা\u200cরের দাম বল\u200cলে ভাল',
#  'ঝাল খাওয়া মজা আলাদা , সাথে পারবেন',
#  '* কেমন বাসস্থান । মরার জাই । আল্লাহ হেফাজত করুন । আমিন । *',
#  'ভাই গালি কথা বলিনি',
#  'শয়তান শয়তানি , বইসা বইসা পুলিশের শয়তানি',
#  'শুনতে আসিনি টা ছেলে মেয়ে এসেছি',
#  'বাংলাদেশ - মেডিকেল ছাত্র ভূটানের প্রধান মুন্ত্রী বাংলাদেশীরাও গর্ববোত , চমৎকার',
#  'হ হ হ জয়বংবন্ধু জয় , জয় ক্যাসিনো',
#  'ঝাল খাওয়াই অঅভ্যস্ত',
#  'চখের পানি আটকাতে পারলাম । কান্না যায়গায় , মেয়ে আমিও মিথ্যামামলায় অনেকদিন জেলে ছিলাম বাট মেয়েরা কখনো আসেনি , সবাই মেয়েরা বাবাকে ভালোবাসে বাট বেলায় । ?',
#  "বেচে আছি , সুস্থ আছি , আল্লাহর সবচেয়ে বড় নেয়ামত , অসুখ হ ' লে মনের ভাবনায় আসে , বুজা যায় কথাগুলো ভালো লাগলো ,",
#  'দেখার লাইক + কমেন্ট করলাম । কারন খাইদাই মানেই খাবার । খালেদ ভাই উপস্থাপনা এক কথায় অসাধারন',
#  'খাওনের লইগ্গা প্রত্যকে ঢুকলে',
#  'ভাই , আসেন খাই কথাটা বলবেন । গাল দিয়া রস',
#  'নাটক টাকা ইনকাম ইউটিউবে চেয়ে বেশী ইনকাম ব্যাপারই',
#  'খিচুর মজা পাসে আছি পাসে ভাইয়া',
#  'ধরার বোঝা যাই ভালো মনদ',
#  'দাম । কারা',
#  'ভাগ্য ভালো বিটিভির লোকেরা পায়নি , পেলে গুম পেলতো , কারন বিটিভিতে দেশ সিংগাপুর , বাস্তবতা টাকার অভাবে বাচ্ছারা পড়তে পারেনা',
#  'ভাই , ব্রাজিল আর্জেন্টিনা ? যেটা সাপোর্ট , আমিও সাপোর্ট করবো ! গেঞ্জিটা লাগবে',
#  'টিশার্টে ইনডিয়ান লিখে বিদেশে ভারত প্রমোট করতেছেন । বাংলাদেশ দোষ করলো',
#  'সম্পর্কের দিক উনার ভাগ্নে',
#  'মানুষ পুলিশের অস্থা পায়না কিভাবে পুলিশের প্রাণী বিচার আসতে আরো লক্ষণীয় বিষয় দেশের ভিতরে অনিয়ম দুর্নীতি মামলা কারণেই হনুমান রা বিচার দাবি এসেছে হায়রে বাংলাদেশ আরো',
#  'আগামীকাল সারা বিশ্বে হরতাল হরতাল হরতাল',
#  'রাজশাহীতে আসার ধন্যবাদ । কাটাখালি যাইয়েন । ওইখানের গরুর কালাভুনা টা মজা',
#  'এরাই মানুষ আহহা । ভাল লাগ্লো',
#  'দাদা ডক্টর দেবী শেঠীর কা\u200cছে বেঙ্গা\u200cলোর কিভা\u200cবে ট্রিট\u200cমেন্ট নেয়া যা\u200cবে একটা ভি\u200cডিও প্লিজ প্লিজ প্লিজ',
#  'এক কথায় অসাধারণ । মন চাইতেছে চট্টগ্রাম এখনি ছুইটা আসি',
#  '১৩০০ টাকা দিয়ে খেলেন ভাগারের মাংস মরা মুরগি',
#  'আচ্ছা ছাই , সাজেক যাবো চান্দের গাড়ী দিয়ে আসবো , মানে ওইদিন থাকবো , ওবং থাকার পরের চান্দের গাড়ী পাবো আসার',
#  'যমুনা নিউজ আপনাদের থেনক্স',
#  'কারো বলবে । বোকারা ছাড়া সবাই জানে মাওয়া ঘাট , গাবতলি , সায়েদাবাদ টার্মিনাল এলাকার খাবারের মান জঘন্য খারাপ',
#  'পড়াশোনা টা চালিয়ে ভালো হতো',
#  'আল্লাহ বাংলাদেশে কিয়ামত নাজিল কর । মানুশ অসহাই হয়ে পরেছে',
#  'হায়রে কুত্তালীগ , হায়রে খানকি মাগীর বাচ্চা পুলিশ',
#  'শিরিকি কথা বল ভাই । তওবা কর সময় এখনো । কাঠের ব্যন্চ বাচায় । আল্লাহ কাঠের ব্যন্চ উচিলায় বচিয়েছেন দুইটি মানুষ । আল্লাহ সর্বশক্তিমান',
#  'ফাজিলের বাচ্চা , তুই মালাউন নাস্তিক , মুসলমান ধরনের কমেন্ট',
#  'পোলা মাইয়ারা কারনেই গাঞ্জাখোর',
#  'ধন্যবাদ চাই , এতটুকু বলি অন্যকে সাহায্য আল্লাহ সাহায্য',
#  'এগিয়ে জাও রানা পাসে আছি',
#  'দেশি আছেন ব্যাবহারেই বুঝেছি প্রত্যেক মেনু খাবার দাম আপনাদের অভ্যাস । কারা',
#  'জব স\u200d্যাটিসফ\u200d্যাকশান ছাড়া পাবলিকঃ দিমু',
#  ', বুঝেন ভাই , বিজনেস',
#  'ভাইয়া ঘুরে আসলাম আসলেই অসাধারন',
#  'মোহাম্মদ সাল্লাল্লাহু আলাইহি ওয়া সাল্লাম মক্কায় জন্মগ্রহণ',
#  'ভাইয়া ফেসবুক গ্রুপ / পেজ ? সাহায্যে গ্রুপের সাথে ঘুড়তে',
#  'এইটা একদমই এইগুলা লটারি বন্ধ আরো মানুষের স্বপ্ন ভেঙে এভাবে মানুষকে স্বপ্ন দেখিয়ে ভেঙে ফেলে মানুষের স্বপ্ন দেখায় ভাঙ্গে মানুষের মন ভাঙার অভিযোগে শাস্তি মানুষকে স্বপ্ন দেখায়',
#  'ভুকা নাঙ্গা কাংলাদেশী একেই',
#  'বাংলাদেশী ১ টাকা = ১ । ৩২ নেপালি রুপী । ভাই খাবারের দাম বলার সময় বাংলাদেশী টাকায় হিসাব বইলেন স্ক্রীনের কর্নারে লিখে',
#  'কলকাতার স্ট্রিটফুড , হইলেই মন চায় । এত্ত এত্ত বাহারি সস্তায় পাওয়া যায় ! অবাক বিষয় । কলকাতায় প্রচুর খাই',
#  'ছোট ইলিশ বাকা কেটে বড় দেখানো । এসব মাছ ঢাকা কিনে আনা । পদ্মার । পদ্মা পার হয়ে বাড়ি যাই । বাধ্য',
#  'আইটেম কিন্ত কম প্রাইজ । কেম্নে । বাংলাদেশ প্রাইজ কমপক্ষে ৫ ৬ হাজারের কম হতো',
#  'হোটেলের খাবার হোটেলের স্টাফরা ভালো',
#  'এইসব বেসসির বেটা পুলিশ রে রোজ 2 3 চুদা দরকার । খায়ার দেয়ার দরকার । পুলিশ গুলার জন্ম বেসসি খানাই । জন্মের হদিশ এমুন বেড়াই । এক এক শুয়োর চুদা',
#  'লটারি দালালরা সবগলোই মাদারচুদ ভালো পেলেও চায়',
#  'ভজহরি মান্না । এটাও বাঙালি খাবারের',
#  'টাকা খুউউব ভাল্লাগে । পেইড রিভিউ পকেটে কাড়ি কাড়ি টাকা ঢুকিয়ে দেয়া , দেখেও দেখার ভান',
#  'টাকা কামানুর বেপসা মাদার চুতেরা',
#  'দেশে প্রতারক দের প্রশাসন , বিছার',
#  'দেহমিলনের সম্পূর্ণ আশা কারোর , দেশ চালাবে',
#  'ভাইয়া শামুক ইসলামে জায়েজ',
#  'হায়রে তবীব ভাই , দারুন্নাজাত মাদ্রাসার বড় ভাই মোদের',
#  'দেশের দেশের রাষ্ট্রপ্রতির অবস্থা এরকম দেশের অবস্থার উন্নতি',
#  'ভিডিওতে কিছক্ষণ গাড়ি যাওয়ার দৃশ্যের দরকার ? আরো একজনের সাথে খাবারটা শেয়ার করুন । নাহলে রিভিউ কতটা খাবার নষ্ট । সত্যি দাম যুক্তিসংগত',
#  'বগুড়ার চুন্নু মামার মুরগির চাপ গুরুর চাপের রিভিও । মামার চাপ মজা',
#  'দ্বাদশ্যাং শুক্লপক্ষস্য মাধবে মাসি মাধবঃ-',
#  'ভাই ওনাদের বলবেন ফুড পান্ডা সাথে জয়েন্ট । ভাল মাঝেমধ্যেই খেতে পারবো',
#  'জানোয়ার দের কারণে অস্ত্র হাতে , পতিতার বাচ্চাদের জংগি হয়ে যাই',
#  'বেডা খায় কেমনে । ছুছা বেডা',
#  'শখের সানগ্লাস টা হারানোর অংশটা',
#  'হিজড়াদের চিড়িয়াখানা বন্ধ করো',
#  '89 কেজি ছিলাম 78 কেজি ! প্রত্যেকদিন করলেও দশ প্রকারের দশটা পুশআপ দেই ! আপনাদের পুশ আপেরেই উপদেশ দিব',
#  'এসব কুত্তার বাচ্চাদের নুনুর আগা সুতা ভালো বেধে ইলেকট্রিকের খুটির সাথে ঝুলিয়ে দরকার',
#  'ওয়াও আপনারেও ভাবি খাওয়ায় দিছে । ভালো লাগলো',
#  '1 । ভারতের দিয়ে যাবার ভারতের ভ্রমন ভিসা লাগবে',
#  'বড় ভিডিও ? এডিট পয়সা , ৩০ মিনিটের ভিডিওর গাড়ি ভ্রমণে দশ মিনিট শেষ',
#  'কোলকাতা ঘুরতে গিয়েছিলাম দারুন জায়গা , খাওয়া দাওয়ার কোলকাতা অবশ্যই',
#  'ফ্রেন্ড ছাই । বয় ফ্রেন্ড । ছরি গার্ল ফ্রেন্ড ।',
#  'চালাকির রাজরানি মাকেও রেখেছে',
#  'মতে সেরা হোটেল পাঁচ ভাই জত সিলেট গেছি ততবার খাইছি অসাধারন খাবার',
#  'বেজন্মা পুলিশ পুলিশ জাতি কলংকিত',
#  '* কাচ্চি কাঁচা মাংস মেরিনেট রান্না বিরিয়ানী হায়দ্রাবাদী লখনৌয়ের দম বিরিয়ানী , তফাত উপকরণ সমূহের । স্বাদ গন্ধে কোনটাকেই খাটো উপায় , সবারি স্বাদ ভিন্নতা আলাদা বৈশিষ্ট্যের সমাদ্রিত । *',
#  'একটা আস্ত মাছ কিনে খেতেন আপ্নারা ভালো হতো',
#  'দেখলাম মাশরাফির বাড়ি মোস্তাফিজের বাড়ি দেখাতে । গরীব মোস্তাফিজের বাড়ি দেখায়',
#  'ফকির কোথাকার ! শব্দ খায় । গবেট ! জাবি বলি , জানবিবিগিরি আসছে গর্দভ',
#  'শালা নির্দোষ প্রচার বলেছে ?',
#  'দর্শককে আলাদা বাহুল্য',
#  'অভিনয় র\u200d্যালী ! বাংলাদেশের শত্রু',
#  'আপনারা রাস্তায় কানা খাইলেন এলাকায় ঘড়',
#  'খুবই বাজে রান্না পরিমাণ কম । দাম । রান্না বাজে । গেছিলাম যাবো',
#  'কথাগুলো জানি মনের সাথে একেবারেই মিলে যায় , আসলে এভাবে ভাবতেও , ভাবেন , যাক আল্লাহ আপনাকে , সবাইকে ভালো রাখুক , ভালো , আল্লাহ হাফেয',
#  'বোরহানি খাদ্যও , মদ্যও । খাদ্য উত্তেজক । বাইরের স্টার্টার স্টার্টার এক । করলা ভাজিও স্টার্টার , বিয়ে বাড়িতে টিকিয়া বোরহানিও স্টার্টার',
#  'ভাই , আপনে শুকাইলেন ক্যামনে ? ত চিনতেই । করসিলাম ছোট ভাই',
#  '* বেটা নাটকে চান্স পাস , রাস্তায় রাস্তায় খাবার চেটে বেরাশ । মন দে । *',
#  'অহংকার বলছে । বাষট্টি মিটার মাটি সরে ঝুরে ধাক্কা দিলে পড়বে । আল্লাহ চাইলে সবই সম্ভব । তবুও দোয়া , দেশের সম্পদ , আল্লাহ রক্ষা করুন । আমিন',
#  'ব্রাজিলের সরকার ইচ্ছে আমাজন পুরাচ্ছেন',
#  'ভাইয়া পিজা বেস্ট নাপুলিতানো ইতালিয়ানো পরিবেশ জনগণ পরিবেশন ইতালির নরমাল খেয়ে আলহামদুলিল্লাহ',
#  'দুপুরের খাবার খেতে কয়টার',
#  'অপরাধী ভাইরাল কইরা এইসব গান ভাইরাল দরকার',
#  'জীবনটাকে ঝুঁকি মুক্ত চাইলে ব্যবসা ঝুঁকি নেন । চায়ের দোকানদারি রাস্তায় হেটে হেটে বিক্রি । ৩ মাস চাকরির অপেক্ষা',
#  'খেলা কখনো দল দিয়ে চলেনা । আশরাফুল ইমরুল কায়েস ওপর অবিচার',
#  'ছিলো । নয়ের খাই - দাই ডট কমের রেটিং পাওয়া মুখের কথা',
#  'ভূটানি সস প্রাণ কোং সস তব সস ভাল',
#  'অাগে শুনছিলাম ৫ ভাই রেস্টু ; খাবার ভাল সস্তা । ধন্যবাদ',
#  'সাময়িকভাবে বহিষ্কার করুক । বাবারা স্থান দিক । দেখার বিষয় ফাঁসি চাই',
#  'কানে রিফাত হত্যার বিচার , কানে হনুমানের বিচার , হাসবো কান্না করব , হাইরে ডিজিটাল বাংলাদেশ দেখাবে',
#  'মাগির পোলারা সবসময় বাউতাবাজি দেয় । কুত্তার বাচ্ছারা মানুষটাকে পাওনা দিয়ে দে',
#  'হায়রে বাংলাদেশের আইন শৃঙ্খলাবাহিনী , বাংলাদেশে অন্যায় সংঘটিত , কয়টিতে পুলিশের হাত থাকতেই । ক্লান্তিলগ্ন দিনে বাংলাদেশের প্রধানমন্ত্রী হতাম , পুরো পুলিশ কাস্টম ব্যান্ড ঘোষণা করতাম',
#  'বাঘের বাচ্চা । নাটক শেষে পড়লো',
#  'আহা , সত্যি , আদনানের কষ্ট দুচক্ষে যায় ! এতই দরদ , ওনাকে বাড়িতে ডেকে ডেকে খাওয়ান ? খেতে চায় সবই খাওয়ান',
#  '80 % যুবক পণ্ আসক্ত দৈনিক হাতমারে',
#  'আগেও আপনাকে মাইকেল ধবাতে আসার কমেন্ট করেছিলাম',
#  'পুলিস , বাংলাদেশের শুক্র',
#  'জানোয়ার দিয়ে দেশ ভইরা , আল্লাহ তুমিই একমাত্র ভরসা , এইসব জানোয়ারদের গজব নাজিল করো তাড়াতাড়ি',
#  'কলকাতার সবচেয়ে নোংরা খাবার মেলে',
#  'সুলতান ডাইনের অপর পাশে জিংলি় নামের একটা চাইনিজ রেস্টুরেন্ট এখানকার থাই সুপএবং অনথণঅনেক টেস্ট ঐটাতে ট্রাই আশা ভালো লাগবে',
#  'ইউনিভার্সিটিতে চেয়ে ভয়াবহ অবস্থা । একজন ভিক্টিম । খোজ দেখেন',
#  'মেহেদী ভাইয়া কিছুটা , বাংলাদেশের চলচ্চিত্র নায়ক বাপ্পির মত লাগে',
#  '১০০০ সাব পূর্ণ হওয়াই শুভেচ্ছা রইলো :',
#  'মশাই রাবরী তে ? জিলাবির ? মিস দাদা ভাই',
#  'বর্তমান সময়ে ৩০ টাকায় চাইনিজ ফুড আশা । আপুটা খাবার দিচ্ছে । মিনি চাইনিজ টা আরো বড়',
#  'ক্ষমতা থাকলে , সবাই অপব্যবহার । গনতন্ত্র । ক্ষমতা পরিবর্তন কেমনে.',
#  'চ্যানেলটায় ঘুরে আসেন আশা আপনাদের ভালো লাগবে',
#  'আয়োজক কমিটির লোকজনরে পাইতাম ধইরা খোজা কইরা দিতাম',
#  'জন্মের রাস্তায় কুকুর , বিড়ালের সাথে বড় হইছে , বাবা , মার শিক্ষাটা পায় কিভাবে বড়দের সাথে কথা । কিভাবে অপরিচিত মানুষের সাথে কথা',
#  'আল্লাহর তৈরি পবিত্র জায়গা তে ইসরায়েল ভারত কখনো পারবে',
#  'উপরের তিনটা উন্নত দেশের রাষ্ট্রপ্রধানদের সাথে দেশের রাষ্ট্রপতির মিল , সবাই যায়গায় ফালতু কথা আসলে সিরিয়াস কথা প্রয়োজন',
#  'সমরাট খারাপ কুততাবাচচারা',
#  'এইটুকু জায়গাই২০ মানুষ বাচ্চাকাচ্চা কম জার তারো ৫ ৬ বাচ্চা এগুলো কমান',
#  'যেংান দিয়ে ঝর্ণা পড়তেছে ওখানেও উঠে ছিলাম',
#  'আরে ভাই এগুলা বাদ , বাংলাদেশের একটু এভাবে নজর প্লিজ `` `` বাংলাদেশের বন্যার কারনে মানুস ঘর বাড়ি হারিয়েছে , প্রতিবেদন , সবাই সাহায্য',
#  'একাত্তরে বেচে এক বুদ্ধিজীবী',
#  '? ফুড র\u200d্যাঞ্জার আগেও দেখিয়েছেন',
#  'সুদীপা দি এত্ত টাকা করো হ্যা । ? বাংলাদেশ রেস্টুরেন্ট ভোক্তা অধিকার মামলা দিতাম বুঝেছো',
#  'মাদারের চোদেরা লটারি চাড়ে 14 গুষ্টির মারে চুদী । সরকার লটারি বন্দ । খানকির পোলারা বিজন্মা',
#  '* বঙ্গীয় অঞ্চলে পুর্ব পশ্চিম বঙ্গ ১৫০০ বছর একশো শতাংশ বাঙালী হিন্দু কিভাবে জনসংখ্যা ৪০ ৪৫ শতাংশে থামলো কট্টর মৌলবাদীর চিন্তা ভাবনা সহজেই বুঝতে পারলাম । *',
#  'খাবারের স্টাইল্টা অনেকটা মতনই বিগ বাইট দিলে মন প্রান ভরে , হা হা হা খুবই ভালো লেগেছেরে ভাই , গো এহেড',
#  '2 টা জিনিস খুবই ভাল লাগে । এক হাসি ( হা হা হা ) `` বৌ , বৌ `` ওয়ার্ডটা',
#  'দেশে টাইপের পিজ্জা কম কারন পিজ্জা বানানোর বড় যেই চুলাটা ওইটা দেশে , ওভেন বেকডই সাধারণত পিজ্জা',
#  'প্রশ্ন ঠিকাদার ডিউটি পালন টাকা পেটে যাই , যনগনের টাকাই চুরি হয়ে যাই , হুনুমান , হয়ত বোঝাতে এসেছিলো',
#  'পারলে সবাই মিলে হাছিনাকে চুদ',
#  'পাপন একটা মাদারচোদ .ওরে জুতা দিয়া পিটাইয়া টান টান দরকার .',
#  'হিল্লোল প্রজন্মের ছেলে বাবা মা বাঙালিয়ানা শেখায় নি । ঢাকার এলিট সোসাইটির মুসলিম পরিবারের ছেলে । বাঙ্গালিয়ানা হিন্দুয়ানী । খাবারে কষে পেয়াজ দিয়ে খায় । এছাড়া জানে',
#  'লিপু ভাইয়াদের মিস করব বাকি ব্লগ গুলোতে',
#  'গলার ছিরি , দেশের মানুষ পাগলে পরিণত । যতসব আজিরা জিনিসে ইন্টারেস্ট',
#  'এসব পজিশনের লোকরাই , খারাপ ভাল দুইটাই',
#  'ময়মনসিংহ ভোঠান চাচ্ছি বাড়ি যেহেতু ময়মনসিংহ ডিস্ট্রিক্ট রিটার্ন টিকেট সংগ্রহ করবো জানাতেন একটু প্লিজ',
#  'দয়াকরে ভারতের ঘুরে বাংলাদেশী খাবারের বলগ বানান ভারতের খাবারের বলগ দেক্গে নিন দেশের বানান বাংলাদেশী চায়না আমদের দেশে আসুক',
#  'ভিডিওটা সেভাবে দেখি নি আলাদা দেখার । এক্সপ্রেশনগুলো দেখছিলাম । ফানি',
#  'ঐদিকে বিকালবেলা প্রচুর বড়লোকের ছানাপোনাদের আগমন ঘটে , চাচার ডিমান্ড বেড়ে',
#  'এগুলো বেস্যা পতিতা মাগির পোলা',
#  'নরসিংদী সদরে দেশ প্রিয় রোড আলমগীর হোটেল বাচ্চুর হোটেলে খাবার খেয়ে আসা ভালো লাগবে',
#  'দেশ উন্নতির 16 বছরে স্মাট পারলে ভোট ব্যাবস্তা নির্বাচন কমিশন ইনশাল্লাহ্',
#  'হেলাল ভাই খাওয়ার মুখে দেওয়ান ধরলে জিব্বা কম বের পছন্দ সবকিছু পছন্দ',
#  'জুতা দিয়া পিডাইতে মন চায় সালাগরে',
#  'সিলেটে বিখ্যাত ভাই পানসি রেস্টুরেন্টে ভাত ঘন ডাল ফ্রি , আনলিমিটেড ইচ্ছা খান',
#  'শংকৱ নৃতালয় ভাৱতে',
#  'গতকাল সন্ধ্যার গেসিলাম',
#  'মামা হোটেল খাওয়া হইছে । ঈ ঠিকঠাক পরিবেশ টা আরেকটু উন্নত পারতো',
#  '16 : 17 বাশ খাচ্ছি',
#  'লটারী বেচাকিনা বন্ধ',
#  'সানি সাইড আপের ওভার ওয়েল এগ সারভ',
#  'খাবারের রিভিউ পারল গেলো কলকাতার বাঙ্গালির খাবারের রিভিউ । বাংলাদেশীরা এসব রান্না খেয়ে স্বাদ পাব । রান্না বাজে ধরনের',
#  'একদল লোক বলবে ডিসি ত ভালা',
#  'এইগুলা নিশ্চই এন পন্থী হনুমান , আওয়ামীলীগ সরকার কর্তৃক খাবার বাবদ বরাদ্দকৃত অর্থ পৌছায়',
#  'মানুষ জাবে কার আইন টাকা কিচু সম্বাব',
#  'ফালতু বিরিয়ানি খেয়েছি । খেয়ে কানে দরেছি জিবনেও আল্লাহ জেন নানেয় ফালতু বিরিয়ানির দোকানে',
#  '২৭ টাকা মাইরা দিছে , বাবুল ভাইয়ের চ্যানেল পর্নোগ্রাফির ভিডিও বানায়',
#  'সপ্তাহে প্যাঁয়ে যাবেন । সময়ের অভাবে ওটা এডিট হয়নাই : (',
#  'সদরঘাট পাটুয়টুলীর কাশ্মীর কাচ্চি ঘরের ফুড রিভিউ চাই',
#  'ছাত্র লীগ , ছাত্র দল , ছাত্র শিবিরের রাজনীতি নিষিদ্ধ',
#  'দেশের পুলিশ হায়েনার চেয়ে অধম',
#  'নি , পাপ্য দরকার , দেশের মানুষ আস্থা হারাবে',
#  'অল্প কথায় বর্ননা কঠিন । হোম ডিস্ট্রিক্ট বরিশালের পটুয়াখালি অঞ্চলের মানুষ ঝাল খেয়ে অভ্যস্ত , ছোট বেলা তরকারিতে ঝালের পাশাপাশি মা আপুকে ভাত খাওয়ার সময় অতিরিক্ত বোম্বাই মরিচ খেতে বড় হয়েছি অভ্যস্ত',
#  'জেনিয়ারা সময় শিক্ষাত সিম্পল',
#  'খান মিস্টি মুখ পুরিয়া , স্বাদে মন ভরিয়া',
#  '৭৮০ টাকা কেমনে সম্ভব । মাথা নষ্ট দাম এতো কম কেমনে সম্ভব । কম দামে কিছুর স্বাদ । ভাবা যায়',
#  'সুদীপা ভোদাই । সরি ফর ব্যাড কমেন্টস',
#  "খাবারের স্বাদ বর্ণনা শব্দ ব্যাবহার , বোঝা গেলো ' আদার ব্যাপারী জাহাজ বেচতে এসেছে । ' উ উ ' এগুলো ? ছি , রুচিই নষ্ট হয়ে গেলো",
#  'সারাদেশে অপরাধী খুঁজুন , আরো হয়ে হন্যে',
#  'সব\u200cই একটা কষ্ট রয়ে , , কাকিমার নিমন্ত্রণ পেলাম এখনো',
#  'দোয়া ভাই তুই আরো সামনের এগিয়ে যাও শুভকামনা রইল❤❤❤',
#  "কোশ্চেন টা ত এরকম পারত । ' লুঙ্গি খুলে সাতার কাটবেন কিভাবে ? ' '",
#  'ভাই টোক বাজারে হোটলের খাবর একটা এপিসোড',
#  'আরবি বিভাগ স্টুডেন্ট । কথা । হালায়',
#  'ধন্যবাদ ভাই যাবো তারাতারি',
#  'পলুসির কারনে দেসটা সেস হয়ে জাইতাছে',
#  'সিজার কিভাবে পেট কমাবে',
#  'বাংলাদেশ আইন , দেশ একদলিও শাসন সরকার ক্ষমতা থাকার জন্যে পুলিশ চাপ পারেনা , পুলিশ সুযোগ দেশে পুলিশ খারাপ যাইতেছে । ভাল লাগে বাংলাদেশ , পারিনা সাধীন দেশের মানুষ',
#  'অক্তপাস অ স্কুইড খাওয়া মুস্লিমদের হারাম',
#  "লোকমান বাঁচলে পাপনও বাঁচবেনা , এতো ' গুণ বাহানা '",
#  'আরে ভাই বিডিও দেখলে ঘনটা হয়ে',
#  'নেক্সটে ইংলিশ সাবটাইটেল দিবেন ভাই',
#  'আদনান ভাই দেখি জ্বিবলাই পানি আইসা পরছে',
#  'আপা মন্ত্রীদের ঘরবাড়ি একটা ভিডিও বানাইতেন তাইলে দেশবাসী পারতো চুরির দিক এগিয়ে',
#  'বিএনপি সরকার চাঁদাবাজকে জীবন ধরতেন । আরো এদেরকে আশরাফুল রয় । এমনকি বিদেশে বিদেশে চাকরির নিয়োগ । এম্বাসিতে এরকম রেকর্ড',
#  'দোকানদারটা আসলে সিলেটি , বাইরে সিলেটি থাকছে । কথাবার্তা দেখেই বুঝা যায় । কারন সিলেটিরা বাইরে আসা মেহমানদরন আন্তরিক । যেটা সবারই',
#  'ভিডিওগ্রাফার সুইচ করুন । বাজে ক্যামেরাওয়ার্ক এগোনো',
#  'কিরে অভিনয়ের ভাত অনলাইনে হালাল ছাগল',
# ...
#  'দেশে পশু পাখি সয়তানে জিম্মি গলি রক্ষা হক',
#  'পরিচয় এভাবে প্রকাশ শ্রেয় । ভদ্র লোকদের স্থান',
#  'থাক , ব্যাপার টানতে ইচ্ছা । বাদ',
#  'জাহিদুল ভাইকে পুরো কৃতিত্ব দিলাম । ❤ ️ ❤ ️ ❤ ️',
#  'ওয়ারি টিকাটুলিতে কীসের ওপর শো যায় ? সাজেশন',
#  'ইন্ডিয়ার সভাপতি ক্রিকেটার , দেশের রাজনীতিবিদ , হায়রে পদ',
#  'অপরিচন্ন পরিবেশের খাবার খাওয়া',
#  ', আপনারটাও বাংলা । বয় ইংরেজি শব্দ । আসল বাংলা গলির পোলা গল্লির পুলা ! :',
#  'বাংলা কলেজে ছাত্রলিগের নাম ভেংগে চাদা তুলছিল ছেলে',
#  'কোটিপতিদের ১ লাখ টাকা',
#  'ভাই ভিডিও দেখলে ভালো লাগে আজকের ভিডিও রিভিউ ভালো কিন্ত এসব সস্তা দোকানের খাবারের ভিডিও ভালো',
#  'হাল্কা একটা ব্যাকগ্রাউন্ড মিউজিক উচিৎ ছিলো । কেমন যেনো মের মেরে লাগতেছে',
#  'টাকা কামানুর বেপসা মাদার চুতেরা',
#  'বাইনচুদে খালি গরুর মতন খায়',
#  'উচ্চারনটা তেহেরী ভাই আসল উচ্চারণ তেহারী , ! বিরিয়ানী উচ্চারণ বিরানি হয়না',
#  'তাড়াতাড়ি পৃথিবী ছেড়ে অজানার দেশে অতি উত্তম জায়গা',
#  'গরিবের আলুর দম বড়লোকের আলুর দম ❤ ️ ❤ ️ ❤ ️',
#  'রেখো তোমাদের দম',
#  'ক্যামেরা মেন বলবেন ভাইয়া খাচ্ছেন খাবার ভিডিও খাবার ভিডিও',
#  'ভাইয়া ভাত খেলেন তিন প্লেট , খাবারগুলো খেলেন । ভাত খেয়ে অল্প অল্প খেয়ে দেখালে ভালো । খাওয়ার সিস্টেমটা',
#  'ভীনদেশি চ্যানেলের অনুষ্ঠান ইংরেজি বল্লে ? লজ্জা আপনাদের ! ফেব্রুয়ারি আসলে মায়া কান্না কাদবেন ভাষার',
#  '6500 টাকা পড়েছিল ( ব্যাচেলরদের )',
#  'সাংবাদিক একজন বন্ধু একজন নিরাপত্তা রক্ষক সাংবাদিক চাই অসহায় মানুষটির টাকাগুলো পায়',
#  'সাবস্ক্রাইবার মিলিয়ন পার ! স্বপ্ন দেখি বিশ্বাস ওটা দ্রুতই !',
#  'টাইগারদের শেষের লিরিকটুকু',
#  'যেহেতু মিডিয়ার সাথে জড়িত , ভাল সুরকার দিয়ে চ্যানেলের থিম দাড়া ফেলেন । দেশি হোটেল , নামই মালেকের হোটেল সাথে দেশি মাছ , মুরগি পুরো ব্যাপারটার সাথে ইংরেজি গান',
#  'ধন্যবাদ আপনাকে , এতো কষ্ট সুন্দর মনোরম দৃশ্য দেখানোর',
#  'ধন্যবাদ সাহসী রিপোর্ট জনসম্মুখে পরিবেশনের',
#  'রাসটু পতিকে পিয়াংকা পাত্তাও দেয়নাই রাস্টু পতি বেবেচিলেন পিয়াংকা উনার বাসায় আসবে তাকেদেকে হাতমারবে সেআসা পুরন হলোনা উনার',
#  'শুভ শারদীয়া বড়পূজার শুভেচ্ছা অভিনন্দন রইলো',
#  'ভাই বাপে একটা বাড়ি কইরা দিয়া যাইতো অাপনাদের মত গুইরা গুইরা খাইতাম অার ফালাইতাম',
#  'বালি ভ্রমণের ভিডিও গুলো অসাধারণ । সাবসাবলীল প্রানবন্ত উপস্থাপনা । ভালো লেগেছে',
#  'ওনার জবাবদিহি আল্লাহর , ? চরকায় ত্যাল',
#  'অপচয়কারীকে উপরওয়ালা পছন্দ',
#  'পাপনকে সুজনকে নাননুকে তিনজনকে গ্রেফতার দরকার',
#  'ইঞ্জিনিয়ারিং শেষ মাছের ব্যবসা ভালো কথা , হয়ত ইঞ্জিনিয়ারিং ভালো জ্ঞান রাখতেও । কৃষি মাছ পড়াশুনা , নিজেকে মাছের তথ্য সম্পর্কে জান্তা সমশের ভাবা মূর্খামির',
#  'দেখলাম মাশরাফির বাড়ি মোস্তাফিজের বাড়ি দেখাতে । গরীব মোস্তাফিজের বাড়ি দেখায়',
#  'সালা তোরে খাইতে কইছে',
#  'ছিঃছিঃ ছিঃ লজ্জা । অবৈধ , লোভ ছিঃ',
#  'ভাইয়া ছাঙ্গু লেকে বরব',
#  'ম্যাডাম চেয়ে ভালো ক্যামেরা থাইল্যান্ড ফুড ট্রিপ',
#  'সবই রিলিজ । কাফের পাচ্ছেন',
#  'ধরনের কর্মকর্তার শালার পুতগরে লটকাইয়া মারার , দুর সরকার এগুলা',
#  'ফাহিম ভাই ভাবীকে এতো কস্ট দিয়ে ভিডিও নেন',
#  'ভুইলা যাইমু রানা তোমারে',
#  'ভাই একজন প্রফেশনাল লোক , আচোরনেই বোঝা যায় । খাবার বাচ বিচার অনিহা । সত্যিই আপনিই । ভালো ভাই',
#  'বাসার দারোয়ানের ছেলের বয়স ৯ বছর ৯ বছরের বাচ্চা জানে বুয়েটে একটা ছেলেকে খুন , বুয়েটের ভিসির কাছেই তথ্য । তথ্য শুনলে গালে নিজেকে থাপ্রাইতে ইচ্ছা',
#  'মুখে দিই বললে বুঝতেই পারিনি , মুখে দিচ্ছিলেন গাঁড়ে দিচ্ছিলেন',
#  'সৌদিআরব মিশর আরব আমিরাত ইহুদীদের দালাল',
#  'একটা মুসলিম দেশে একজন ক্বারী এতো উৎসাহ দেখিনা মানুষের দেখি গানে । হয়তো সবাই আইডির তাকাচ্ছেন',
#  'আওয়ামীলীগ দেশের শত্তুর জনোগনের হায়না',
#  'মেয়েদের নিরাপত্তা বাংলাদেশে বললেই । দুইদিন পরপর ধর্ষনের খবর পাওয়া যায়',
#  'হায়রে বাংলাদেশের মানুষ চ্যানেল রেন্ডিয়ার দালাল , ওদিকে ইন্ডিয়া মিয়ানমার কিলোক্লাস সাবমেরিন দিচ্ছে বিষয় মিডিয়ার উচ্চবাচ্চ',
#  'কপাল , তোমায় জঘন্য রেস্টুরেন্ট রেকমেন্ড ? বাড়ি আসতে , ডাল ভাত খেতে শান্তি',
#  'ভালো লাগলো প্রচেস্টা । কলকাতার বাসিন্দা এখনো দার্জিলিং যেয়ে উঠতে পারিনি নানান কারনে । ভিডিওটি ভালো লাগলো যাওয়ার ইচ্ছেটাকে আরো প্রবল তুললো । শুভেচ্ছা নেবেন',
#  'ভাইয়া রংপুরেও । কিন্ত দাম ৬০ টাকা । পুলিশ লাইন্স স্কুলের আগের গলি তে । চাইলে আসতে রংপুরে । খাবারের ভালো রেস্টুরেন্ট । ☺',
#  'সাংবাদিক ভাই সুন্দর বলছেন পাপন শুনবে',
#  'সাধারন মানুষের সাথে ইয়াবা থাকলেযে শাস্তি পুলিশের হয়না ? বাংলা দেশে পুলিশ লাভ সাথে ইয়াবা থাকলে বর্তমানে পুলিশ থাকার চেয়ে থাকাই ভালো',
#  'সায়েম ভাই ভিডিওগুলো ভালো লাগে । সেন্টমার্টিন দ্বীপ 5টি ভিডিও ব্লগ তৈরি করছি ভিডিওগুলো দেখবেন আশা',
#  'বাল ফালাইয়া খান ভাই',
#  'সৌরভের সাথে অমিত শাহের ডিল হইসে বিসিসিআই সভাপতির পরিবর্তে সৌরভ 2021 সালে বিধান সভার নির্বাচনে বিজেপিকে সাপোর্ট । ( সূএ ; রাহুল কুনাল , ইন্ডিয়া টুডে )',
#  'খুবই নিকটে সুসময় আসছে ইনসাআল্লাহ্',
#  '4 টিম 5 দিনের ট্যুরে পার হেড আনুমানিক 20000 টাকা পড়বে',
#  'এইকিছুদিন ২ টাকা বানায় দেছেরে ভাউ',
#  'নিকৃষ্ট জাতী বাংলাদেশ পুলিশ',
#  'পড়াশোনা টা চালিয়ে ভালো হতো.',
#  'নীলা মার্কেট ঢাকার কোথায়',
#  'অাবার গা\u200cনের ভিতর প\u200cরে না\u200cকি',
#  'ভাই আমিও যাবো বউ কমোট লো কোমট ? হাই কোমটে হাগতে । বাইরে ভেকেশনে যাই হাগার',
#  'পুরান ঢাকায় রাস্তায় চকলেট কোল্ড কফিও এভাবেই বানায় , হারসিছ সিরাপ , দুধের আইস কিউব , নেসকেফে । দাম ৪৫ টাকা । খেতে মজা । ওটা খেয়েও হইছিলো , গরমে কোল্ড কফি লাগে না☺',
#  'সদিচ্ছা থাকলে এরকম দুরুহ সম্ভব হতো । সমাজের প্রতিটি জায়গায় দুর্নিতি বন্ধ নিত্য প্রয়োজনীয় দ্রব্যের মান সহনীয় রাখতে পারলে দেশেের জনগন দলকে ক্ষমতায় চাইবে',
#  'এরকম ছোটলোকের মত খাবার ব্যাক্ষা ? টিভিতে রাঁধুনিরাও এরকম । উফফ্\u200c',
#  'ভাইয়া প্লিজ জানাবেন আপনাদের মত দুইজন বইলে ঘুরতে খরচ । ইনক্লুডিং সবকিছু',
#  'বুয়েটে ? সারাদেশে ছাত্ররাজনীতি বন্ধ হবেই , নইলে পাবলিক ইউনিভার্সিটি গুলো বন্ধ হউক',
#  'ইন্ডিয়ার টিরিস্ট ভিসা । ভুটান চাই ইন্ডিয়ার ট্রানজিট ভিসা লাগবে ? টুরিস্ট ভিসা দিয়েই ইন্ডিয়া ক্রজ ভুটান পারবো । ভাইয়া দয়া একটু জানাবেন প্লজ',
#  'দরকার 16 মেয়ে নিয়মিত নিচতলা ভাঁড়া দিতো',
#  'কিনা বিসিবি এতই আপন ,',
#  'বৌদি মাইকেল ধাবাতে আসবেন',
#  'মিডবাজেট রেস্টুরেন্ট গুলো রিভিউ ভালো',
#  'বাংলাদেশী ভাই দেখলাম বলছেন দাম টা কম বলছি বিল টাই বাংলাদেশ টাকায় ১০০০ ছড়িয়ে',
#  'সাংবাদিকের একজন ক্ষমতা',
#  'সিলেট কমেএকটা সিঙ্গেল রুমের হোটেল ভারা দেখান',
#  'ভাইয়া বাংলাবাজার কেফে করনার সকাল বিকেলের নাস্তা পরেন , আশা ভাল লাগবে',
#  'বলবিয়ার প্রেসিডেন্ড',
#  'আবারও বলছি , একজন ব্যবসায়ী হিসেবে অযোগ্য চাকরি দিয়ে কখনোই ক্ষতি',
#  'কফি এক্সপ্রেস , মিরপুর 11 নং বাস স্ট্যান্ড পশ্চিমে । ইয়ান রেস্টুরেন্ট পেছনে',
#  'ভালই লাগে পকেট সায় দেয়',
#  'সমস্যা কেয়ামতের সময় আসছে',
#  'গালিবয় হয়ে গল্লিবয় হইলে ভালো হইতো যেহেতু বাংগালী',
#  'ভাইয়া , খাবার বিসমিল্লাহ',
#  'হাতি নেয়েছেন টাকা দিয়েছেন',
#  'ভিডিওটি ভালো লাগলো ভাই এরকম প্র্যাকটিক্যালি বুঝাইয়া দিলে বুঝতে সুবিধা',
#  'মানোনীয় প্রধান মন্ত্রীর হস্থক্ষেপ চাই - - - -',
#  'সম্ভব , যেদিন ব্যাক সেইদিন বিকালের শিফটে সাজেক ব্যাক',
#  'অসাধারণ আনকাট ভিডিও আশাকরি ভালকিছু পাব',
#  'অপকর্মের সাথে পুলিশ জড়িত কমন বিষয়',
#  'ভাইয়া আপনাদের সাথে টুর , টিম সদস্যা',
#  'ধান্দাবাজকে শাস্তি দেওয়ার দরকার',
#  'মাদারি তুরে হাজতে নিবার দরকার , কিসনা লিলা খেলা , ? আশরাপকে বিপদে পেলে কই আল্লাহ একজন',
#  'আনোয়ার সাহেবের হোটেল বর্তার নামকরা',
#  'এলাকা বাসী জুতা পিটা ওদেন বিচার',
#  'আল্লাহ ভয় । অাল্লাহ চাইলে চেয়েও ভয়াবহ পৃথিবী ধ্বংস । নমুনা',
#  'পাপনের পাছায় দুইটা লাততী মারে এখান বের ঊচিৎ',
#  'বেকার রা কই আছো , সপনো দুধ চুরি কোরলেই চাকুরি , চিন্তা',
#  'কথাটা সত্যি হৃদয় চুঁয়ে',
#  'অভিনন্দন , সকল পুলিশ সুপার এরকম হতো , দেশটা শান্তির নিড়ে পরিনত হতো । আবারও অভিনন্দন , পুলিশ সুপারকে',
#  'পাপনকে রিমান্ড । পাপন কুওার বাচ্চা ক্রিকেট টিমকে নষ্ঠ অপরাধিকে বাচাতে চায় । পাপন হারামির বাচ্চার ভাল ভাল খেলোয়ারের জীবন ধংস হয়ে । আশরাফুলের শাস্তি পাপন লোকমানের শাস্তি',
#  '3 । 60 ডিগ্রি অনুরোধ করছি তদন্ত প্রতিবেদনে দেখাবেন',
#  'চ্যাংরাবান্ধা বুড়িমারি',
#  'অ্যাপলের প্রতিদ্বন্দ্বী ভবিষ্যতেও । স্মার্ট ইউজার গেমার বিষয়টি ভালোভাবেই জানে',
#  'ছাত্রলীগের উপস্থিতি আবরারের কাঁদাবে',
#  'দাম মানে অসাধারন । মেবি ২০১০ সালে খাইসিলাম',
#  'আরেকটা ইনফো দেই , গ্রেভি কারি । কষা রসা । কষা মশলা অনেক্ষন ভুনা । রসা কম মশলা পাতলা ঝোল',
#  'ভালো আইফোনের দাম কমিয়ে দিলে একটা কিনুম',
#  'ক্যামেরা ম্যান খাওয়ালে সাথে নেন',
#  'বাংলাদেশের পুলিশরা বেশিরভাই মাদারি ঘুশ খায় হোগা মারে',
#  'খাবার মেনু পালটাবেন',
#  'আসতে চাই । কাইন্ডলি ঠিকানাটা জানাবেন প্লিজ',
#  'মিয়া যাও কনে , জম্মের নাস্তা , হাত চেটে খাচ্ছো , কয়টা বাংলা য় যাও',
#  'আজকে দাঁতে ময়লা পরিষ্কার পারছে ভাই এগুলা ক্যামেরার ছি ছি ছি',
#  'কালা জানি পাবো । ভাই কেমেরা ম্যান খায়',
#  'বল্যতে আপু । পরের ভিডিও তে বলার ট্রাই করবো । সরি :',
#  'দাদা বুড়া গেলেন',
#  '2 । কেমন ঝাল খেতে',
#  'প্রমান হয়ে । ফাশি । আগামিতে বাংলাদেশ আরো আবরার হারাবে । শাস্তি ভবিষ্যতে সাহস পাবেনা',
#  'আশরাফুল পাপন মাইয়ারে চুইদা গাবিন',
#  'বাসার পাসে কাকুর দোকান',
#  'পুলিশরা খাওয়ার সবসময়ই বলবে জানেনা',
#  'দুঃখে বুক টা ফেটে গেলো , চোর সুদীপা',
#  'হা হা সাতার কাটবো বউয়ের সাতে',
#  'কাঠের বেঞ্চ আল্লাহর রহমতে হ\u200cইছে । কাঠের বেঞ্চ একটা ওছিলা',
#  'স্বাস্থ্যকর খাবার , ব্রেকফাস্ট মিস দেয়া , আর্লি ডিনার , ফিটনেস ট্রেইনিং । এইতো',
#  'কথা শুনে পুরা বেহুশ',
#  'হোটেল মালিক নিঃসন্দেহে একজন মহান ব্যক্তি । রীতিমত মানব সেবা । টাকায় কিভাবে দিয়ে ব্যবসায় টিকে আছেন , আল্লাহ ভালো জানেন । হোটেল মালিকের দোয়া করছি । একজন আলোকিত মানুষ',
#  'এসব পথশিশু গরীব দুঃখী কপচানো ভুগিচুগি বাদ দিয়া ফ্রি কনডম বিতরণ ভালো । এক একটা ফইন্নি ইচ্ছামত ৪ ৫ টা কইরা টোকাই জন্ম দেয় কামলা খাটায়া টাকা কামায়',
#  'ছোট ভাই শাহিন বন্ধু',
#  'বাংলা কলেজে ছাত্রলিগের নাম ভেংগে চাদা তুলছিল ছেলে',
#  '4 : 32 সেকেন্ডে `` মাই গট ``',
#  'ইন্ডিয়ান দের লাগে , আইডি কার্ড টা দেখালেই ভুটান ঢুকতে দেয়',
#  'এতো দাম ? - গরুর গস্ত বিদেশ আনা',
#  'সাবেক জিম্বাবুইয়ান বলিং কোচের সময় বাংলাদেশ মুস্তাফিজ , তাসকিনদের ফাস্ট বলার পেয়েছে । ভালো ক্রিকেটার ছিলো',
#  'টাইগারদের শেষের লিরিকটুকু',
#  'স্বপ্ন সুপার শপের ভাইরাল মার্কেটিং কৌশল । সহজ এডভার্টাইজ',
#  'কেমন মানবীকতা হায়রে বাংলাদেশ',
#  'ভাইয়া , হাতিরঝিলের শাহী ঝাল মুড়ি খেয়ে । সাথে জিড়াপানি আছেই',
#  'সাধারণত চ্যানেলে সাবস্ক্রাইব । খাবারের ভিডিও মানে বর্ণনা দেওয়ার কেীশল \u200dআমাকে সাবস্ক্রাইব বাধ্য । সত্যি বলার কৌশলটা দারুণ লাগে । ধন্যবাদ',
#  'ময়মনসিংহ বাশি গর্বিত । এমনই প্রধানমন্ত্রী চাই । দেশে টা ভেবে পরের জন্ন ভাবেন',
#  'আদনান ভাই , কতো বিল হয়েছিলো',
#  'পুলিশি রাষ্ট্রে আশা যায় পুলিশের',
#  'পাপনে শেষ দিচ্ছ বিসিবি',
#  'খানিকির পুতের দেশে মাগির পুতের বসবাস',
#  '@ মেহজাবিন চৌধরী ত ছেলে মেয়ের পিক লাগিয়ে আছো চুদো শালা',
#  'নিরিহ মানুষের অন্যায় অত্যাচার করোস তোদের জানোয়ার পুলিশ রাস্তা ঘাটে গাড়ির তলে মরে থাকিস',
#  'উন্নয়নের চোদনে মানুষ বিচার পায় পুলিশ পোষাক দারি সন্ত্রাসী',
#  'সত্যের সন্ধানে নির্ভীক সাংবাদিকতাকে স্যালুট । ধন্যবাদ যমুনা টিভি । দেশের প্রাইভেট চ্যানেলগুলোর সবচেয়ে বস্তুনিষ্ঠ দর্শকপ্রিয় চ্যানেল',
#  'খবর শুনে , পাবলিক ভার্সিটিতে ভর্তি পরীক্ষা দেই । জীবনে নাও মা বাবার সাথে থাকতে পারবো ?',
#  'তোমাদের জয় সর্বক্ষেত্রে',
#  'পুলিশের কাছেকি গ্রহণযোগ্য',
#  'ভোজ কোম্পানি থালি ভাল',
#  'লজ্জা লাগে বাংলাদেশ স্বাধিন হইছে , হাইরে দালাল পুলিশ একদিন আসবে তদের জনগণ পিটাইয়া মাইয়া ফেলবো',
#  '১ । নয়েস ক্যানসেল কঠিন , তবুও সময় সফ্টওয়ার বেজড নয়েজ ক্যানসেলিং সাউন্ড টা অসম্ভব ভালো লাগবে',
#  'বাংলাদেশের মানুষকে কথা চাই কেয়ামতের সময় ন্যায় বিচার আল্লাহ তাআলা ঠকাবেন',
#  'সমাবেশ মিডিয়ার , বঙ্গবন্ধুর আদর্শের সন্তান , তারাই দেখি হত্যা খুন জমি দখল ধর্ষণ আরো কাজের সাথে সম্পর্কাতা আরো , আল্লাহ সীমালংঘনকারীদের পছন্দ',
#  'গান গাওয়াতে মিডিয়া এসেছে । সুন্দর কোরান তেলাওয়াত মিডিয়াতে আসেনা',
#  'পুলিশের আস্থা যায় । হাতে ইবা পকেটে ঢুকুয়ে দিয়ে টাকা হাতিয়ে নিচ্ছে',
#  'ছানা মুখি মিষ্টিটা একটু দামি । যাই , মিষ্টি একটা পছন্দ করলেও , পেলে তারিয়ে তারিয়ে খান । ভালো লাগলো । পরের পর্বের অপেক্ষাতে রইলাম । কলকাতা ভালোবাসা নেবেন',
#  'প্রধানমন্ত্রীর ছত্রছায়ায় বিরোধীদের দমন সারা দেশেই বেপরোয়া ভোট চোর আওয়ামীলীগের সন্ত্রাসীরা এরকম উগ্রতা চালাচ্ছে , মানুষ কথা ভয় পায় , জীবনের নিরাপত্তা',
#  'বিলিভ যায় । বাংলাদেশ গুজব ছড়ানোর একটা কারখানা',
#  'আদনান ভাই সালাত খাওয়ার রাগ করলাম',
#  'ভিডিওর প্রথমে সালাম দেননাই ভাই',
#  'হাজারো সাংবাদিক গুম ফেলেছে অতীতেই , দেশ চালায় পুলিশ লীগ',
#  'সয়তান অনুসরন',
#  'বাংলাদেশের পুলিশ সবচেয়ে বড় সন্ত্রাস কারণে মানুষ ভয় পায় একটা মানুষ পুলিশকে বন্ধু ভাবতে পুলিশ দেখলে ভয় পাই এগুলো জানোয়ার',
#  'ওনাকে ভুল সুদ্দারানুর শুজুকটা হয়েছে পুলিশ সুপার ধন্যবাদ',
#  'পুলিশ অফিসর জাহিদুল ইসলামের আনেক ধন্যবাদ',
#  'বাংলাদেশের কুলাঙ্গার পুলিশ অপকর্ম সকল পুলিশের ওপর গালি বাংলাদেশ পুলিশ নামটা একটা কলঙ্ক',
#  '২৫০ টাকা প্লেট ভাত ২৯০ টাকা প্লেট মাটন',
#  'অারে ভাই আপনারা রুজা রাখেনি রুজার দিনে খাবেন । হে রাতরে খাবেন কুনু সমস্ষা । আপনাদের ভিডিও গুলা ভাল লাগে',
#  'এক সময় সরকারের আমিও সাপোর্টার ছিলাম অনেকাংশে উনাদের পরিচালনার ধরনে ঘৃনা জন্মে',
#  'ডান হাতে গ্লাভস বাট বাম হাতে । বাম হাত দিয়া গোস্তোও ধরতাসে । লাব ডান হাতে গ্লাভস পইরা',
#  'অস্ট্রেলিয়া দেখছি , চ্যানেলটিও ঘুড়ে আসুন প্লিজ',
#  'দেশ টা গুল্লায় , ইচ্ছা হইতেছে করতেছে',
#  'প্রশাসন কর\u200cছে , একজন মানুষ প্রাপ্য থে\u200cকে ব\u200cঞ্চিত হ\u200cবে',
#  'হা হা ভাইয়া মত মাছের তেল গরু চর্বি পছন্দ আমিও পছন্দ',
#  'ভাইয়া একজন ভোজন রসিক একটু ঢিলেঢালা পোষাকে বেশী মানায় , খাদ্য রসিকতার সাথে সাথে কিন্তুু শারীরিক এক্সপ্রেশন গুলিও আমাদেরকে খাবারের প্রলোভন তিব্র জাগ্রত , আশাকরি বিষয়টা আমাদেরকে ভালবেশে পসেটিব্লি নিবেন , ধন্যবাদ ♥',
#  'ভাই সবই ভাল লাগল কিন্তুু বাম হাত দিয়ে খাবার দিচ্ছে ভাল লাগল',
#  'চেয়েছি তোমায় ফোসকা',
#  'ঢাকা এপ্লাই সাধারণত 3 কর্মদিবস লাগে । আবহাওয়া ভালো থাকার কথা । এখনি মূলত সিজন চলছে',
#  'অস্ট্রেলিয়া দেখছি , চ্যানেলটিও ঘুড়ে আসুন প্লিজ',
#  'ভুটানের ভিসাতে টাকা লাগে',
#  'বাংলাদেশ বিচার , মারো মরো',
#  'বাহিনীতে অযোগ্য অদখ্য লোক বাহিনী ততটাই দুর্নীতি গ্রস্ত',
#  'জানতাম পুলিশের হাত , তু জন্মের টিক , কান্কির বাচ্চারা পুলিশ',
#  'অামি করলাম গালিবাজ ছেলে',
#  'আসলে নারায়নগঞ্জ থাকি খুশি হইয়া গেসিলাম',
#  'একটা অনুরোধ । জানিনা রাখবেন কিনা । খিলগা , বনশ্রী এলাকার বুফে রেষ্টুরেন্ট গুলো রিভিউ চাই । অঙ্গন',
#  'কোলকাতা হয়ে ঘুরা পথ হয়ে যায় । জেলায় ? দার্জিলিং কলকাতা হয়ে নিউ জলপাইগুড়ি জেতে । দার্জিলিং',
#  'ভালো হয়েছে ( ছাত্র রাজনীতি স্থায়ীভাবে নিষিদ্ধ )',
#  'লালবাগ এলাকা ঢাকার শহরে রাত্রেবেলা কাজগুলো আজকে সাংবাদিক এতকিছু মানুষের সাথে ব্যবহারগুলো',
#  'দেশে এইটা কনো বেপার । সবাই মারহাবে কথা পারবেনা',
#  'গোপালগঞ্জের বাবু ভাই চটপটি দত্তের সন্দেশ রসগোল্লা খেয়ে । খাবার সুস্বাদু খাবার দুইটার পর্থক্য বুঝতে পারবেন',
#  'হাসি , ধারা বর্ণনা ভিডিও সুন্দর । সেনাবাহিনীতে কর্মরত',
#  'যুগান্তর সম্রাট নিউজ 22 টা',
#  'কৃত্রিমতা বর্জিত রিভিউ , চালিয়ে ভাই',
#  'আসলেই জানেন বিশ্বের সেরা ? জেনে আবোল তাবোল লিখে একটু গবেষণা নিন ! ফ্যাক্টরি স্থাপত্য নকশা কোম্পনির ! ২০০৯ সালে সারা বিশ্বের সবচেয়ে নম্বর পেয়ে ফ্যাক্টরি নকশার লীড প্ল্যাটিনাম পুরস্কারে পুরস্কৃত হয়েছি !',
#  'পাপন একটা মাদারচোদ । ওরে জুতা দিয়া পিটাইয়া টান টান দরকার',
#  'মসজিদ গলি , মিরপুর 10 নাম্বার গোলচক্করের সাথেই',
#  'হানিমুনের মত রিফ্রেশরিং',
#  'সবাই লটারি কেনা বন্ধ , সবাইকে জানিয়ে',
#  'পাপন রে তুই সুর পাল্টাছ কেনো । আশরাফুলের সময় বললি ট্রাইবুনালের থাকবি । শাস্তি টা দিয়ে দিলি । কেনো বলছিস বিচার । বিচার করোছ কেনো',
#  'খাবারের ভিডিও বানান পানি থাকতে দম দেয় জানেন রান্না শিখবেন',
#  'ভাই মালাই চিকেন টা ভালো',
#  'আদনান ভাই পাকিস্থানের গিলগিত বালতিস্থান একটা ট্রাভেল ভ্লগ বানান । প্লিজ',
#  'বাংলাদেশের গুন , নিউজিই । খুন ধর্ষণ একটারও ফাঁসি । লজ্জা লাগে দেশটা মেরুদন্ডহীন দেশ',
#  'দুনীতি সিমা সারিয়ে',
#  'ধন্যবাদ মাননীয় প্ৰধান মন্ত্ৰী শেখ হাসিনাকে',
#  'চুলার কারনেই মুলত পিজ্জার টেস্ট গুন বেড়ে যায়',
#  'গাবতলীর কোথায় কালাই রুটি পাওয়া যায়',
#  'মুসলিম ঘরের সন্তান , কুরআন শিখে মানুষ মত মানুষ হও , মানুষ নামে অমানুষ হইও , দোয়া দুনিয়া আখেরাতটা সাজাও , জীবন কষ্টের , আল্লাহর চাও একমাত্র উনিই ভাগ্য বদলাতে',
#  'আনন্দবাজার পড়ে মাথা ঘুরাচ্ছে এখনো ! মরা পশুর মাংসের বড় র\u200d্যাকেট পড়লো ! দুর্ভাগ্যজনক',
#  'দাদা শূকর টেস্ট বলুন দেখি খেলে আমিও খাবার সাহস করবো',
#  'জ্বী , দেশে কষাও',
#  '*কাঙলু শালা এশিয়ান পেইন্টসের ভিডিও চুরি আপলোড দিলি । *',
#  'বাসাবোতেও বাবা রাফি রেস্টুরেন্ট ওপেন হয়েছে । আসবেন প্লিজ',
#  'আলহামদুলিল্লাহ্ , কথা শুনে মনটা ভরে , প্রাপ্তি , দোয়া ভাই , আপনাদের দোয়ার জোরেই এতদূর আসতে পেরেছি',
#  'একমাত্র আপনাদের উছিলায় লোকটা টাকা গুলো পেতে',
#  'ভুস্কির পোলারা ভুয়া লটারি',
#  'টেনশনে ছিলাম যাক ভগবানের দায় বেঁচে খুশি হয়েছি',
#  'সুদিপা পুলিশের মেযে টাকা ছিলতে যানে মাটনটা খেলেই পারতেন হয হারাম বলি',
#  'ইন শা আল্লাহ সমস্যা । বাচ্চা টুর দিলে সাথে অবশ্যই কমন ওষুধ গুলো রাখবেন । যেহেতু শীত , বাচ্চার শীতের ভালো প্রিপারেশন রাখবেন',
#  '৬ । ক্যামেরা নাড়াচাড়া মাঝে মাথা যায় । একটু কম নাড়তে বলবেন',
#  'সরকারকে প্রতিভাটাকে জগিয়ে তোলার উদ্দেগ গ্রহন উচিৎ । নিউজ দেখালে সরকারের দৃষ্টি আকর্শন বারবার',
#  'নিজেকে আটকিয়ে রাখতেও পারছি',
#  'ইন্ডিয়া তে বাংলাদেশের সাপোর্ট একমাত্র মানুষ সৌরগাঙ্গুলি',
#  'আচ্ছা অমাজন পুরলে খতি কাররো থাকলে বলুন',
#  'ভাই , ফালুদার রেসিপিটা বুঝলাম । বোতল ওগুলো পানি দিলো ? প্রথমে বরফ পানি লেবু ছিলো গ্লাসে',
#  'বুঝি বাঁচবেন',
#  'ভাই দার্জিলিং বেড়াতে চাই । জানি টাকা খরচ লাগবে । বলবেন প্লিজ',
#  'ভাই , হজ্ব অ্যালকোহল ড্রিংকের দাম প্রকাশ হতো ? পরোক্ষভাবে মাতালদের ড্রিংক সাহায্য , ভালো',
#  'আল্লাহর বিচার চাই লটারির আয়োজকের বউ পোলাপানের অসুখ ৩০ লাখ ৩০ টাকা দিয়েও ভাল',
#  'কুমিল্লা হাইওয়ে বন্ধ হয়ে খেয়ে মরবি',
#  'ভাই ক্যাম্পাসে আসছিলেন । অসংখ্য ধন্যবাদ❤',
#  'বীরপুরুষ ভিপি নুর ভাই , ধন্যবাদ ভাই',
#  'খিচুড়ি পুড়ল',
#  'হাতি দিয়ে টাকা চাঁদাবাজি আয় নিজেরে খায় হাতিদের দিনের খাবার দিয়ে রাখে । এরকম একটা ঘটনা বনশ্রী আফতাব নগরে ঘটেছিলো',
#  'ভাইয়া পুরান ঢাকায় দাওয়াত রইল',
#  'সবাই ছাত্র লীগের বিরোদ্ধে ঔক্য গড়ে তুলতে',
#  ...]

# %%
import ktrain
from ktrain import text
MODEL_NAME = 'xlm-roberta-base'
t = text.Transformer(MODEL_NAME, maxlen=500)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/512 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/1.89G [00:00<?, ?B/s]

# %%
y_train = [str(x) for x in train_cluster_id]
y_test = [str(x) for x in test_cluster_id]

# %%
trn = t.preprocess_train(X_train, y_train)
val = t.preprocess_test(X_test, y_test)
# Out:
# preprocessing train...
# language: bn
# train sequence lengths:
# 	mean : 11
# 	95percentile : 25
# 	99percentile : 33
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: bn
# test sequence lengths:
# 	mean : 11
# 	95percentile : 25
# 	99percentile : 31
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
model = t.get_classifier()
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=10)
history = learner.fit_onecycle(2e-5, 10)
# Out:
# begin training using onecycle policy with max lr of 2e-05...
# Epoch 1/10
# 1258/1258 [==============================] - 963s 745ms/step - loss: 1.0246 - accuracy: 0.4737 - val_loss: 0.8615 - val_accuracy: 0.6110
# Epoch 2/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.8630 - accuracy: 0.6115 - val_loss: 0.7920 - val_accuracy: 0.6602
# Epoch 3/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.7875 - accuracy: 0.6503 - val_loss: 0.7685 - val_accuracy: 0.6614
# Epoch 4/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.7144 - accuracy: 0.6875 - val_loss: 0.7659 - val_accuracy: 0.6892
# Epoch 5/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.6493 - accuracy: 0.7209 - val_loss: 0.7781 - val_accuracy: 0.6923
# Epoch 6/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.5618 - accuracy: 0.7641 - val_loss: 0.7756 - val_accuracy: 0.7049
# Epoch 7/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.4330 - accuracy: 0.8274 - val_loss: 0.8145 - val_accuracy: 0.6992
# Epoch 8/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.3185 - accuracy: 0.8775 - val_loss: 0.9648 - val_accuracy: 0.7062
# Epoch 9/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.2335 - accuracy: 0.9132 - val_loss: 1.0423 - val_accuracy: 0.7131
# Epoch 10/10
# 1258/1258 [==============================] - 932s 741ms/step - loss: 0.1612 - accuracy: 0.9403 - val_loss: 1.1393 - val_accuracy: 0.7081

# %%
learner.validate(class_names=t.get_classes())
# Out:
# 50/50 [==============================] - 10s 131ms/step
#               precision    recall  f1-score   support
#
#            0       0.50      0.49      0.50       361
#            1       0.76      0.79      0.77       654
#            2       0.78      0.75      0.77       571
#
#     accuracy                           0.71      1586
#    macro avg       0.68      0.68      0.68      1586
# weighted avg       0.71      0.71      0.71      1586
# array([[178, 103,  80],
#        [ 98, 515,  41],
#        [ 78,  63, 430]])

# %%
def PlotGraph(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'g', label='Training acc')
    plt.plot(x, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'g', label='Training loss')
    plt.plot(x, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
PlotGraph(history)
